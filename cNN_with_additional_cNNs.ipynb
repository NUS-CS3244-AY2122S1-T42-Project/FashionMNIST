# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix

# %% [markdown]
# I had some difficulties uninstalling pytorch without cuda to replace it so I just created another virtual env and ran it in that. (I think this only needs to be done when you try to run it local)
#
# After activating the venv you can install the pytorch with cuda with the following command.
#
# `pip3 install torch==1.9.1+cu111 torchvision==0.10.1+cu111 torchaudio==0.9.1 -f https://download.pytorch.org/whl/torch_stable.html`

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# torch.zeros(1).cuda() # Uncomment if your device supports cuda

# %% [markdown]
# # Main cNN

# %% [markdown]
# ## Import and Prepare Dataset

# %%
train_csv = pd.read_csv("./fashion-mnist_train.csv")
test_csv = pd.read_csv("./fashion-mnist_test.csv")

# %%
class FashionDataset(Dataset):
    """User defined class to build a datset using Pytorch class Dataset."""
    
    def __init__(self, data, transform = None):
        """Method to initilaize variables.""" 
        self.fashion_MNIST = list(data.values)
        self.transform = transform
        
        label = []
        image = []
        
        for i in self.fashion_MNIST:
             # first column is of labels.
            label.append(i[0])
            image.append(i[1:])
        self.labels = np.asarray(label)
        # Dimension of Images = 28 * 28 * 1. where height = width = 28 and color_channels = 1.
        self.images = np.asarray(image).reshape(-1, 28, 28, 1).astype('float32')

    def __getitem__(self, index):
        label = self.labels[index]
        image = self.images[index]
        
        if self.transform is not None:
            image = self.transform(image)

        return image, label

    def __len__(self):
        return len(self.images)

# %%
# Transform data into Tensor that has a range from 0 to 1
train_set = FashionDataset(train_csv, transform=transforms.Compose([transforms.ToTensor()]))
test_set = FashionDataset(test_csv, transform=transforms.Compose([transforms.ToTensor()]))

train_loader = DataLoader(train_set, batch_size=100)
test_loader = DataLoader(test_set, batch_size=100)

# %% [markdown]
# All the above has been done to load data in batches into the model. We use the DataLoader class from torch.utils.data. We also initialize the device to be used as the GPU instead of CPU.
#
# The FashionDataset class has two methods:
# - get_item(index) -> image and label of item at index
# - len() -> number of items in the dataset

# %%
# Mapping label number to a more meaningful label

def output_label(label):
    output_mapping = {
        0: "T-shirt/Top",
        1: "Trouser",
        2: "Pullover",
        3: "Dress",
        4: "Coat", 
        5: "Sandal", 
        6: "Shirt",
        7: "Sneaker",
        8: "Bag",
        9: "Ankle Boot"
    }
    input = (label.item() if type(label) == torch.Tensor else label)
    return output_mapping[input]

# %% [markdown]
# ## Extras

# %%
# displaying image using matplotlib imshow()
image, label = next(iter(train_set))
plt.imshow(image.squeeze(), cmap="gray")
print(label)
# Out:
# 2

# %%
# plt.figure(figsize=(10,10))
# for i in range(25):
#     plt.subplot(5,5,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid(False)
#     plt.imshow(train_images[i], cmap=plt.cm.binary)
#     plt.xlabel(class_names[train_labels[i]])
# plt.show()

# %%
demo_loader = torch.utils.data.DataLoader(train_set, batch_size=10)

batch = next(iter(demo_loader))
images, labels = batch
print(type(images), type(labels))
print(images.shape, labels.shape)
# Out:
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([10, 1, 28, 28]) torch.Size([10])

# %%
grid = torchvision.utils.make_grid(images, nrow=10)

plt.figure(figsize=(15, 20))
plt.imshow(np.transpose(grid, (1, 2, 0)))
print("labels: ", end=" ")
for i, label in enumerate(labels):
    print(output_label(label), end=", ")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# labels:  Pullover, Ankle Boot, Shirt, T-shirt/Top, Dress, Coat, Coat, Sandal, Coat, Bag,

# %% [markdown]
# ## Main cNN Model

# %% [markdown]
# 1. Make a model class (inherits nn.Module class)
# 2. Add Layers to model class
#
#     a. Convolution layer with kernel size 3*3, padding = 1 (no padding) in 1st layer and padding = 0 in second layer. Stride of 1 in both layers.
#
#     b. Batch normalization layer
#
#     c. Activation function used: ReLU
#
#     d. Max Pooling layer with kernel size of 2 * 2 and stride 2.
#
#         i. flatten out output for dense layer
#
#         ii. 3 fully connected layers with different in/out features
#
#         iii. 1 dropout layer with p=0.25
#
# Summary is as follows:
#
# First conv layer -> Max Pooling layer -> Second conv layer -> second max pooling layer
#
# 28 * 28 * 3      --> 28 * 28 * 32      --> 14 * 14 * 32      --> 12 * 12 * 64              --> 6 * 6 * 64
#
# Final fully connected layer has 10 output features for 10 types of clothes.

# %%
class FashionCNN(nn.Module):
    def __init__(self):
        super(FashionCNN, self).__init__()
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc1 = nn.Linear(in_features=64*6*6, out_features=600)
        self.drop = nn.Dropout2d(0.25)
        self.fc2 = nn.Linear(in_features=600, out_features=120)
        self.fc3 = nn.Linear(in_features=120, out_features=10)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.drop(out)
        out = self.fc2(out)
        out = self.fc3(out)
        
        return out

# %%
model = FashionCNN()
model.to(device)

error = nn.CrossEntropyLoss()

learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
print(model)
# Out:
# FashionCNN(
#   (layer1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=2304, out_features=600, bias=True)
#   (drop): Dropout2d(p=0.25, inplace=False)
#   (fc2): Linear(in_features=600, out_features=120, bias=True)
#   (fc3): Linear(in_features=120, out_features=10, bias=True)
# )

# %%
train_accu = []
train_losses = []

def train(model, optimizer, loader, epoch):
  model.train()

  running_loss=0
  correct=0
  total=0
  
  for images, labels in loader:
    # Transfering images and labels to GPU if available
    images, labels = images.to(device), labels.to(device)
    
    # Forward pass 
    outputs = model(images)
    loss = error(outputs, labels)
    
    # Initializing a gradient as 0 so there is no mixing of gradient among the batches
    optimizer.zero_grad()
    
    #Propagating the error backward
    loss.backward()
    
    # Optimizing the parameters
    optimizer.step()

    running_loss += loss.item()
    
    _, predicted = outputs.max(1)
    total += labels.size(0)
    correct += predicted.eq(labels).sum().item()
      
  train_loss=running_loss/len(loader)
  accu=100.*correct/total
  
  train_accu.append(accu)
  train_losses.append(train_loss)
  return train_loss, accu

# %%
eval_losses=[]
eval_accu=[]
 
def test(model, loader, epoch):
  model.eval()
 
  running_loss=0
  correct=0
  total=0
 
  with torch.no_grad():
    for images, labels in loader:
      images, labels = images.to(device), labels.to(device)

      outputs = model(images)
      loss = error(outputs, labels)

      running_loss += loss.item()

      _, predictions = outputs.max(1)
      total += labels.size(0)
      correct += predictions.eq(labels).sum().item()
   
  test_loss=running_loss/len(loader)
  accu=100.*correct/total
 
  eval_losses.append(test_loss)
  eval_accu.append(accu)
 
  return test_loss, accu

# %%
epochs=100
train_accu, eval_accu, train_losses, eval_losses = [], [], [], []
for epoch in range(1,epochs+1):
  train_loss, train_accuracy = train(model, optimizer, train_loader, epoch)
  test_loss, test_accuracy = test(model, test_loader, epoch)
  print("Epoch: {}\nTrain: Loss: {}, Accuracy: {}%\nTest: Loss {}, Accuracy: {}%".format(epoch, train_loss, train_accuracy, test_loss, test_accuracy))
# Out:
# Epoch: 1
# Train: Loss: 0.06663820112706162, Accuracy: 97.59%
# Test: Loss 0.5274680384248495, Accuracy: 90.01%
# Epoch: 2
# Train: Loss: 0.060926013235778856, Accuracy: 97.775%
# Test: Loss 0.5329993315041065, Accuracy: 90.26%
# Epoch: 3
# Train: Loss: 0.06440783503077303, Accuracy: 97.63%
# Test: Loss 0.6182557560503483, Accuracy: 89.05%
# Epoch: 4
# Train: Loss: 0.06258446081502674, Accuracy: 97.75166666666667%
# Test: Loss 0.5758040510118008, Accuracy: 90.18%
# Epoch: 5
# Train: Loss: 0.0581088570439412, Accuracy: 97.94166666666666%
# Test: Loss 0.549696566388011, Accuracy: 90.4%
# Epoch: 6
# Train: Loss: 0.05834370049492767, Accuracy: 97.85833333333333%
# Test: Loss 0.5855675140023231, Accuracy: 90.31%
# Epoch: 7
# Train: Loss: 0.056595924258969414, Accuracy: 97.89333333333333%
# Test: Loss 0.5760934975743294, Accuracy: 90.45%
# Epoch: 8
# Train: Loss: 0.05756540748368328, Accuracy: 97.95166666666667%
# Test: Loss 0.5767984490096569, Accuracy: 90.47%
# Epoch: 9
# Train: Loss: 0.0541786967854326, Accuracy: 98.03833333333333%
# Test: Loss 0.6182445055991411, Accuracy: 90.14%
# Epoch: 10
# Train: Loss: 0.05821580421606389, Accuracy: 97.88666666666667%
# Test: Loss 0.6377356550842523, Accuracy: 89.95%
# Epoch: 11
# Train: Loss: 0.05505255122106367, Accuracy: 98.01833333333333%
# Test: Loss 0.6752374796569347, Accuracy: 90.32%
# Epoch: 12
# Train: Loss: 0.04879639291747784, Accuracy: 98.28333333333333%
# Test: Loss 0.6856807528063655, Accuracy: 90.52%
# Epoch: 13
# Train: Loss: 0.0438351418642075, Accuracy: 98.42666666666666%
# Test: Loss 0.6872311151027679, Accuracy: 90.08%
# Epoch: 14
# Train: Loss: 0.046005348128965125, Accuracy: 98.37333333333333%
# Test: Loss 0.6635819225013256, Accuracy: 90.78%
# Epoch: 15
# Train: Loss: 0.04703620762292606, Accuracy: 98.28833333333333%
# Test: Loss 0.6555699047446251, Accuracy: 90.77%
# Epoch: 16
# Train: Loss: 0.046802940135239626, Accuracy: 98.33333333333333%
# Test: Loss 0.6807782870531082, Accuracy: 90.33%
# Epoch: 17
# Train: Loss: 0.039244960705206416, Accuracy: 98.585%
# Test: Loss 0.7089987537264824, Accuracy: 90.46%
# Epoch: 18
# Train: Loss: 0.041843232186317136, Accuracy: 98.49833333333333%
# Test: Loss 0.7289781273901462, Accuracy: 90.49%
# Epoch: 19
# Train: Loss: 0.04339801453519612, Accuracy: 98.40833333333333%
# Test: Loss 0.6615225524455309, Accuracy: 91.25%
# Epoch: 20
# Train: Loss: 0.040561087577758975, Accuracy: 98.58833333333334%
# Test: Loss 0.7469200946390628, Accuracy: 90.38%
# Epoch: 21
# Train: Loss: 0.03893359540956832, Accuracy: 98.61%
# Test: Loss 0.7425087521970272, Accuracy: 90.52%
# Epoch: 22
# Train: Loss: 0.04122028211553697, Accuracy: 98.51166666666667%
# Test: Loss 0.7613444982469082, Accuracy: 89.98%
# Epoch: 23
# Train: Loss: 0.041827066651118606, Accuracy: 98.53166666666667%
# Test: Loss 0.7245098076015711, Accuracy: 90.55%
# Epoch: 24
# Train: Loss: 0.04172633106618984, Accuracy: 98.56333333333333%
# Test: Loss 0.6918312181532383, Accuracy: 90.64%
# Epoch: 25
# Train: Loss: 0.03976960659407875, Accuracy: 98.66666666666667%
# Test: Loss 0.7350243924558163, Accuracy: 90.79%
# Epoch: 26
# Train: Loss: 0.038519122121360855, Accuracy: 98.635%
# Test: Loss 0.7779834203422069, Accuracy: 90.24%
# Epoch: 27
# Train: Loss: 0.03368603277788983, Accuracy: 98.85%
# Test: Loss 0.772802796587348, Accuracy: 90.65%
# Epoch: 28
# Train: Loss: 0.03892715997222695, Accuracy: 98.65166666666667%
# Test: Loss 0.7779973025619984, Accuracy: 90.55%
# Epoch: 29
# Train: Loss: 0.03297092154010897, Accuracy: 98.84%
# Test: Loss 0.7729811945557594, Accuracy: 90.52%
# Epoch: 30
# Train: Loss: 0.03340365994486395, Accuracy: 98.88666666666667%
# Test: Loss 0.7802793680131436, Accuracy: 90.63%
# Epoch: 31
# Train: Loss: 0.032078318419783806, Accuracy: 98.875%
# Test: Loss 0.7392500704526901, Accuracy: 90.97%
# Epoch: 32
# Train: Loss: 0.032991125613989425, Accuracy: 98.84166666666667%
# Test: Loss 0.829999321103096, Accuracy: 90.63%
# Epoch: 33
# Train: Loss: 0.034882046405376364, Accuracy: 98.80833333333334%
# Test: Loss 0.8057850362360477, Accuracy: 90.36%
# Epoch: 34
# Train: Loss: 0.03853415432909969, Accuracy: 98.72%
# Test: Loss 0.7265915079414844, Accuracy: 91.22%
# Epoch: 35
# Train: Loss: 0.028883500851879945, Accuracy: 98.94666666666667%
# Test: Loss 0.8401925902068615, Accuracy: 90.47%
# Epoch: 36
# Train: Loss: 0.031037924845538023, Accuracy: 98.90333333333334%
# Test: Loss 0.909830978512764, Accuracy: 90.14%
# Epoch: 37
# Train: Loss: 0.03515718409820692, Accuracy: 98.84%
# Test: Loss 0.8122759559750556, Accuracy: 90.72%
# Epoch: 38
# Train: Loss: 0.030122878940843898, Accuracy: 98.95833333333333%
# Test: Loss 0.8184928140044212, Accuracy: 90.9%
# Epoch: 39
# Train: Loss: 0.03285087368046031, Accuracy: 98.89166666666667%
# Test: Loss 0.8752789399027825, Accuracy: 90.73%
# Epoch: 40
# Train: Loss: 0.032037040600407636, Accuracy: 98.91%
# Test: Loss 0.8753355005383492, Accuracy: 90.59%
# Epoch: 41
# Train: Loss: 0.03210226462665256, Accuracy: 98.93333333333334%
# Test: Loss 0.8442246329784393, Accuracy: 90.34%
# Epoch: 42
# Train: Loss: 0.029844375636384937, Accuracy: 98.98333333333333%
# Test: Loss 0.9345847854018211, Accuracy: 89.46%
# Epoch: 43
# Train: Loss: 0.02930389409010483, Accuracy: 98.97%
# Test: Loss 0.8357851552963257, Accuracy: 90.82%
# Epoch: 44
# Train: Loss: 0.028171859532121743, Accuracy: 99.06%
# Test: Loss 0.9233390943706036, Accuracy: 90.4%
# Epoch: 45
# Train: Loss: 0.02711007066965976, Accuracy: 99.10166666666667%
# Test: Loss 0.9026221269369126, Accuracy: 90.72%
# Epoch: 46
# Train: Loss: 0.027927703570918918, Accuracy: 99.07166666666667%
# Test: Loss 1.0040679332613944, Accuracy: 90.2%
# Epoch: 47
# Train: Loss: 0.026920636137977755, Accuracy: 99.10166666666667%
# Test: Loss 0.9309280735254287, Accuracy: 90.76%
# Epoch: 48
# Train: Loss: 0.032021098563248716, Accuracy: 98.97666666666667%
# Test: Loss 0.883510481864214, Accuracy: 90.73%
# Epoch: 49
# Train: Loss: 0.028156421789050607, Accuracy: 99.01166666666667%
# Test: Loss 0.8781678527593613, Accuracy: 90.58%
# Epoch: 50
# Train: Loss: 0.02440482347587628, Accuracy: 99.145%
# Test: Loss 0.9003440570831299, Accuracy: 90.82%
# Epoch: 51
# Train: Loss: 0.026860460773867393, Accuracy: 99.10166666666667%
# Test: Loss 0.8776215790212154, Accuracy: 90.29%
# Epoch: 52
# Train: Loss: 0.0227556137304479, Accuracy: 99.19666666666667%
# Test: Loss 0.9480390825867653, Accuracy: 90.42%
# Epoch: 53
# Train: Loss: 0.02711199778370428, Accuracy: 99.08166666666666%
# Test: Loss 0.9524643597006798, Accuracy: 90.27%
# Epoch: 54
# Train: Loss: 0.026599640310438797, Accuracy: 99.12666666666667%
# Test: Loss 0.8866309789568185, Accuracy: 90.73%
# Epoch: 55
# Train: Loss: 0.028529978423066496, Accuracy: 99.04666666666667%
# Test: Loss 0.9366994316875935, Accuracy: 90.41%
# Epoch: 56
# Train: Loss: 0.023193277415618163, Accuracy: 99.23833333333333%
# Test: Loss 1.0017608565092087, Accuracy: 90.24%
# Epoch: 57
# Train: Loss: 0.025767878203708582, Accuracy: 99.15%
# Test: Loss 0.9341906271874905, Accuracy: 90.47%
# Epoch: 58
# Train: Loss: 0.025859353047856835, Accuracy: 99.12833333333333%
# Test: Loss 0.8919860027730465, Accuracy: 90.99%
# Epoch: 59
# Train: Loss: 0.02290400365978106, Accuracy: 99.225%
# Test: Loss 0.9497922150790692, Accuracy: 90.46%
# Epoch: 60
# Train: Loss: 0.027982340199535733, Accuracy: 99.115%
# Test: Loss 0.9968775025010109, Accuracy: 90.24%
# Epoch: 61
# Train: Loss: 0.019823602814794866, Accuracy: 99.30666666666667%
# Test: Loss 0.9297583544254303, Accuracy: 90.78%
# Epoch: 62
# Train: Loss: 0.02289537407498604, Accuracy: 99.245%
# Test: Loss 0.988066844344139, Accuracy: 90.28%
# Epoch: 63
# Train: Loss: 0.028039837765118137, Accuracy: 99.14666666666666%
# Test: Loss 1.0474048395454885, Accuracy: 90.26%
# Epoch: 64
# Train: Loss: 0.02296479924759903, Accuracy: 99.24166666666666%
# Test: Loss 0.9823412072658538, Accuracy: 90.4%
# Epoch: 65
# Train: Loss: 0.02441186155164966, Accuracy: 99.22333333333333%
# Test: Loss 0.9560739903151989, Accuracy: 90.58%
# Epoch: 66
# Train: Loss: 0.024887035753693755, Accuracy: 99.195%
# Test: Loss 0.9678124737739563, Accuracy: 90.49%
# Epoch: 67
# Train: Loss: 0.020322040398744624, Accuracy: 99.32666666666667%
# Test: Loss 0.9875455155968667, Accuracy: 90.31%
# Epoch: 68
# Train: Loss: 0.01983022220793752, Accuracy: 99.33%
# Test: Loss 1.059269560277462, Accuracy: 90.39%
# Epoch: 69
# Train: Loss: 0.024918852755078356, Accuracy: 99.20333333333333%
# Test: Loss 1.0003623606264591, Accuracy: 90.94%
# Epoch: 70
# Train: Loss: 0.022873801933803103, Accuracy: 99.26833333333333%
# Test: Loss 1.089539281874895, Accuracy: 90.01%
# Epoch: 71
# Train: Loss: 0.02550342798262136, Accuracy: 99.18%
# Test: Loss 1.0741492784023285, Accuracy: 90.68%
# Epoch: 72
# Train: Loss: 0.022826880679343353, Accuracy: 99.265%
# Test: Loss 0.9330101642012596, Accuracy: 91.09%
# Epoch: 73
# Train: Loss: 0.01990114047809584, Accuracy: 99.33833333333334%
# Test: Loss 0.9965607495605946, Accuracy: 90.39%
# Epoch: 74
# Train: Loss: 0.022830256404837806, Accuracy: 99.255%
# Test: Loss 1.082838390171528, Accuracy: 89.91%
# Epoch: 75
# Train: Loss: 0.024082868018833022, Accuracy: 99.25%
# Test: Loss 1.0134761632978917, Accuracy: 90.72%
# Epoch: 76
# Train: Loss: 0.02244042469349703, Accuracy: 99.25166666666667%
# Test: Loss 1.0621499034762383, Accuracy: 90.35%
# Epoch: 77
# Train: Loss: 0.023115037192449867, Accuracy: 99.32666666666667%
# Test: Loss 1.058617567718029, Accuracy: 90.38%
# Epoch: 78
# Train: Loss: 0.021697526867440805, Accuracy: 99.31666666666666%
# Test: Loss 1.1124907422065735, Accuracy: 90.72%
# Epoch: 79
# Train: Loss: 0.023592896962745726, Accuracy: 99.29833333333333%
# Test: Loss 0.9878595289587975, Accuracy: 90.7%
# Epoch: 80
# Train: Loss: 0.01710338811995674, Accuracy: 99.41833333333334%
# Test: Loss 1.0421592323482036, Accuracy: 90.58%
# Epoch: 81
# Train: Loss: 0.019840835681449485, Accuracy: 99.34%
# Test: Loss 1.0344876463711261, Accuracy: 90.66%
# Epoch: 82
# Train: Loss: 0.022701104830666737, Accuracy: 99.305%
# Test: Loss 1.026633321493864, Accuracy: 90.84%
# Epoch: 83
# Train: Loss: 0.018665598757296873, Accuracy: 99.41%
# Test: Loss 1.0353990380465985, Accuracy: 90.76%
# Epoch: 84
# Train: Loss: 0.022374201371744677, Accuracy: 99.28833333333333%
# Test: Loss 1.1542812363803387, Accuracy: 90.75%
# Epoch: 85
# Train: Loss: 0.01886340695132882, Accuracy: 99.435%
# Test: Loss 1.0704552140831947, Accuracy: 90.56%
# Epoch: 86
# Train: Loss: 0.01746246260800111, Accuracy: 99.425%
# Test: Loss 1.0732868534326554, Accuracy: 90.59%
# Epoch: 87
# Train: Loss: 0.023355038898327317, Accuracy: 99.29833333333333%
# Test: Loss 1.0645739436149597, Accuracy: 90.27%
# Epoch: 88
# Train: Loss: 0.022113182963263776, Accuracy: 99.33%
# Test: Loss 1.0566609345376492, Accuracy: 90.99%
# Epoch: 89
# Train: Loss: 0.019329585886925238, Accuracy: 99.37833333333333%
# Test: Loss 1.0870964527130127, Accuracy: 90.61%
# Epoch: 90
# Train: Loss: 0.02441271405971444, Accuracy: 99.29333333333334%
# Test: Loss 1.0689814573526382, Accuracy: 90.42%
# Epoch: 91
# Train: Loss: 0.021375034194590324, Accuracy: 99.35833333333333%
# Test: Loss 1.0781573928892612, Accuracy: 90.31%
# Epoch: 92
# Train: Loss: 0.01921213730242319, Accuracy: 99.42333333333333%
# Test: Loss 1.1125931736826897, Accuracy: 90.8%
# Epoch: 93
# Train: Loss: 0.01646855892054949, Accuracy: 99.42833333333333%
# Test: Loss 1.144635689407587, Accuracy: 90.36%
# Epoch: 94
# Train: Loss: 0.01768960106860694, Accuracy: 99.44333333333333%
# Test: Loss 1.108255466222763, Accuracy: 90.61%
# Epoch: 95
# Train: Loss: 0.021684117449169663, Accuracy: 99.37666666666667%
# Test: Loss 1.2166386294364928, Accuracy: 89.63%
# Epoch: 96
# Train: Loss: 0.025810456262518832, Accuracy: 99.24666666666667%
# Test: Loss 1.1147573855519295, Accuracy: 90.13%
# Epoch: 97
# Train: Loss: 0.016713268245502302, Accuracy: 99.47166666666666%
# Test: Loss 1.0704974554479123, Accuracy: 90.69%
# Epoch: 98
# Train: Loss: 0.017967231730460373, Accuracy: 99.43%
# Test: Loss 1.116325391381979, Accuracy: 90.94%
# Epoch: 99
# Train: Loss: 0.021059347077739404, Accuracy: 99.34333333333333%
# Test: Loss 1.1382644012570382, Accuracy: 90.45%
# Epoch: 100
# Train: Loss: 0.020801135550376177, Accuracy: 99.37%
# Test: Loss 1.1333173854649068, Accuracy: 90.68%

# %% [markdown]
# ## Graphs

# %%
import os

if not os.path.exists('./diagrams'):
    os.makedirs('./diagrams')

# %%
plt.figure(figsize=(16,10))

plt.plot(train_accu)
plt.plot(eval_accu)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['Train','Valid'])
plt.title('Train vs Valid Accuracy')

plt.savefig('./diagrams/cNN_Train_vs_Valid_Acc.png')

# %%
plt.figure(figsize=(16,10))

plt.plot(train_losses)
plt.plot(eval_losses)
plt.xlabel('epoch')
plt.ylabel('losses')
plt.legend(['Train','Valid'])
plt.title('Train vs Valid Losses')
 
plt.savefig('./diagrams/cNN_Train_vs_Valid_loss.png')

# %% [markdown]
# From the graph we can see a downward trend of training loss vs epoch. Perhaps a reason for the spikes in loss could be just due to the randomness of the batch sampling. An unlucky sampling could have led to the loss increasing compared to the previous iterations but overall the loss has a downward trend as iterations increase.
#
# However, validation loss generally increases with more and more epochs while validation accuracy fluctuates around 90% throughout. The increase of validation loss could be due to the model overfitting the training data with more and more epochs.

# %% [markdown]
# ## Training Accuracy

# %%
class_correct = [0. for _ in range(10)]
total_correct = [0. for _ in range(10)]
accuracies_train = []

all_labels = torch.Tensor();
all_predicted = torch.Tensor();

with torch.no_grad():
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        c = (predicted == labels).squeeze()

        all_labels = torch.cat((all_labels, labels))
        all_predicted = torch.cat((all_predicted, predicted))
        
        for i in range(100):
            label = labels[i]
            class_correct[label] += c[i].item()
            total_correct[label] += 1
        
for i in range(10):
    accuracies_train.append(class_correct[i] * 100 / total_correct[i])
    print("Accuracy of {}: {:.2f}%".format(output_label(i), accuracies_train[i]))
# Out:
# Accuracy of T-shirt/Top: 98.68%
# Accuracy of Trouser: 99.80%
# Accuracy of Pullover: 98.37%
# Accuracy of Dress: 99.73%
# Accuracy of Coat: 98.87%
# Accuracy of Sandal: 100.00%
# Accuracy of Shirt: 91.07%
# Accuracy of Sneaker: 99.97%
# Accuracy of Bag: 99.78%
# Accuracy of Ankle Boot: 99.23%

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(all_labels, all_predicted)
# Out:
# array([[5921,    1,    5,   14,    5,    0,   54,    0,    0,    0],
#        [   3, 5988,    0,    8,    1,    0,    0,    0,    0,    0],
#        [  10,    0, 5902,    5,   66,    0,   17,    0,    0,    0],
#        [  12,    0,    2, 5984,    1,    0,    0,    1,    0,    0],
#        [   1,    0,   43,   13, 5932,    0,   11,    0,    0,    0],
#        [   0,    0,    0,    0,    0, 6000,    0,    0,    0,    0],
#        [ 297,    0,  117,   60,   62,    0, 5464,    0,    0,    0],
#        [   0,    0,    0,    0,    0,    2,    0, 5998,    0,    0],
#        [   4,    0,    2,    0,    0,    0,    7,    0, 5987,    0],
#        [   0,    0,    0,    0,    0,    3,    0,   43,    0, 5954]],
#       dtype=int64)

# %% [markdown]
# ## Test Accuracy

# %%
class_correct = [0. for _ in range(10)]
total_correct = [0. for _ in range(10)]
accuracies_test = []

all_labels = torch.Tensor();
all_predicted = torch.Tensor();

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        c = (predicted == labels).squeeze()

        all_labels = torch.cat((all_labels, labels))
        all_predicted = torch.cat((all_predicted, predicted))
        
        for i in range(100):
            label = labels[i]
            class_correct[label] += c[i].item()
            total_correct[label] += 1
        
for i in range(10):
    accuracies_test.append(class_correct[i] * 100 / total_correct[i])
    print("Accuracy of {}: {:.2f}%".format(output_label(i), accuracies_test[i]))
# Out:
# Accuracy of T-shirt/Top: 89.00%
# Accuracy of Trouser: 98.20%
# Accuracy of Pullover: 84.50%
# Accuracy of Dress: 92.30%
# Accuracy of Coat: 87.80%
# Accuracy of Sandal: 98.10%
# Accuracy of Shirt: 67.80%
# Accuracy of Sneaker: 97.00%
# Accuracy of Bag: 97.10%
# Accuracy of Ankle Boot: 95.00%

# %%
confusion_matrix(all_labels, all_predicted)
# Out:
# array([[890,   0,  21,  19,   8,   0,  58,   1,   3,   0],
#        [  3, 982,   4,   7,   2,   1,   1,   0,   0,   0],
#        [ 27,   0, 845,  13,  69,   0,  44,   2,   0,   0],
#        [ 24,   7,  11, 923,  17,   0,  16,   0,   2,   0],
#        [  4,   0,  44,  25, 878,   0,  47,   0,   2,   0],
#        [  1,   0,   0,   0,   0, 981,   0,  13,   0,   5],
#        [153,   1,  49,  37,  80,   0, 678,   0,   2,   0],
#        [  0,   0,   0,   0,   0,  10,   0, 970,   0,  20],
#        [  4,   0,   3,   2,   4,   1,  11,   3, 971,   1],
#        [  0,   0,   0,   0,   0,   5,   1,  44,   0, 950]], dtype=int64)

# %% [markdown]
# ## Accuracy Analysis

# %% [markdown]
# **From Training Data:**
#
# Select classes with low classification accuracy:
#
# | Class       | Accuracy (%) | Classes that it is most confused with |
# |-------------|--------------|---------------------------------------|
# | Shirt       | 91.07        | T-shirt/top                           |
# | Pullover    | 98.37        | Coat, Shirt                           |
# | T-shirt/top | 98.68        | Shirt                                 |
# | Coat        | 98.87        | Pullover, Shirt                       |
# | Dress       | 99.73        | T-shirt/top, Coat, Shirt              |
#
#
# **From Test Data:**
#
# Select classes with low classification accuracy:
#
# | Class       | Accuracy (%) | Classes that it is most confused with |
# |-------------|--------------|---------------------------------------|
# | Shirt       | 67.80        | T-shirt/top                           |
# | Pullover    | 84.50        | Coat, Shirt                           |
# | Coat        | 87.80        | Pullover, Shirt                       |
# | T-shirt/top | 89.00        | Shirt                                 |
# | Dress       | 92.30        | T-shirt/top, Coat, Shirt              |
#
# *Note: Findings from test data are solely for understanding purposes and are not used to change the model so as to not data snoop*

# %% [markdown]
# # Additional cNNs

# %% [markdown]
# ## Create and Train Additional cNNs

# %%
# Create additional cNNs that are only trained on those classes with the lowest classification accuracies
# and the classes that they are confused with

confused_classes1 = [0, 6] # consider 0 change to 6, or 6 change to 0
confused_classes2 = [2, 4, 6] # consider 2 change to 4 or 6, 4 change to 2 or 6
confused_classes3 = [0, 3, 4, 6] # consider 3 change to 0, 4 or 6
confused_classes = [confused_classes1, confused_classes2, confused_classes3]

confused_classes1_to_index_map, confused_classes2_to_index_map, confused_classes3_to_index_map = {}, {}, {}
index_to_confused_classes1_map, index_to_confused_classes2_map, index_to_confused_classes3_map = {}, {}, {}
maps = [[confused_classes1_to_index_map, index_to_confused_classes1_map], [confused_classes2_to_index_map, index_to_confused_classes2_map], [confused_classes3_to_index_map, index_to_confused_classes3_map]]

idx = 0
for confused_class in confused_classes:
  for i in range(len(confused_class)):
    maps[idx][0][confused_class[i]] = i
    maps[idx][1][i] = confused_class[i]
  idx += 1

train_csv_subset1, train_csv_subset2, train_csv_subset3 = pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
train_csv_subsets = [train_csv_subset1, train_csv_subset2, train_csv_subset3]

test_csv_subset1, test_csv_subset2, test_csv_subset3 = pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
test_csv_subsets = [test_csv_subset1, test_csv_subset2, test_csv_subset3]


idx = 0
for confused_class in confused_classes:
  train_csv_subsets[idx] = train_csv[train_csv.label.isin(confused_class)]
  test_csv_subsets[idx] = test_csv[test_csv.label.isin(confused_class)]
  idx += 1

train_subset1, train_subset2, train_subset3 = [], [], []
train_subsets = [train_subset1, train_subset2, train_subset3]

test_subset1, test_subset2, test_subset3 = [], [], []
test_subsets = [test_subset1, test_subset2, test_subset3]

train_subset_loader1, train_subset_loader2, train_subset_loader3 = [], [] ,[]
train_subset_loaders = [train_subset_loader1, train_subset_loader2, train_subset_loader3]

test_subset_loader1, test_subset_loader2, test_subset_loader3 = [], [] ,[]
test_subset_loaders = [test_subset_loader1, test_subset_loader2, test_subset_loader3]

for i in range(len(confused_classes)):
  train_csv_subsets[i]['label'] = train_csv_subsets[i]['label'].map(lambda x: maps[i][0][x])
  test_csv_subsets[i]['label'] = test_csv_subsets[i]['label'].map(lambda x: maps[i][0][x])

  train_subsets[i] = FashionDataset(train_csv_subsets[i], transform=transforms.Compose([transforms.ToTensor()]))
  test_subsets[i] = FashionDataset(test_csv_subsets[i], transform=transforms.Compose([transforms.ToTensor()]))

  train_subset_loaders[i] = DataLoader(train_subsets[i], batch_size=100)
  test_subset_loaders[i] = DataLoader(test_subsets[i], batch_size=100)
# Out:
# <ipython-input-34-ad092dec4d5e>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_csv_subsets[i]['label'] = train_csv_subsets[i]['label'].map(lambda x: maps[i][0][x])
# <ipython-input-34-ad092dec4d5e>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_csv_subsets[i]['label'] = test_csv_subsets[i]['label'].map(lambda x: maps[i][0][x])

# %%
class FashionCNN2(nn.Module):
    def __init__(self, num_classes):
        super(FashionCNN2, self).__init__()
        
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc1 = nn.Linear(in_features=64*6*6, out_features=600)
        self.drop = nn.Dropout2d(0.25)
        self.fc2 = nn.Linear(in_features=600, out_features=120)
        self.fc3 = nn.Linear(in_features=120, out_features=num_classes)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = self.fc1(out)
        out = self.drop(out)
        out = self.fc2(out)
        out = self.fc3(out)
        
        return out

# %%
model1, model2, model3 = [], [] ,[]
extra_models = [model1, model2, model3]

optimizer1, optimizer2, optimizer3 = [], [], []
optimizers = [optimizer1, optimizer2, optimizer3]

for i in range(len(confused_classes)):
  extra_models[i] = FashionCNN2(len(confused_classes[i]))
  extra_models[i].to(device)
  optimizers[i] = torch.optim.Adam(extra_models[i].parameters(), lr=learning_rate)
  # print(extra_models[i])

# %%
epochs=100
train_accu, eval_accu, train_losses, eval_losses = [], [], [], []
for i in range(len(confused_classes)):
  print("Extra Model #{}".format(i))
  for epoch in range(1,epochs+1):
    train_loss, train_accuracy = train(extra_models[i], optimizers[i], train_subset_loaders[i], epoch)
    test_loss, test_accuracy = test(extra_models[i], test_subset_loaders[i], epoch)
    print("Epoch: {}\nTrain: Loss: {}, Accuracy: {}%\nTest: Loss {}, Accuracy: {}%".format(epoch, train_loss, train_accuracy, test_loss, test_accuracy))
# Out:
# Extra Model #0
# Epoch: 1
# Train: Loss: 0.18356875951091448, Accuracy: 92.74166666666666%
# Test: Loss 0.3123918078839779, Accuracy: 88.3%
# Epoch: 2
# Train: Loss: 0.1701659460241596, Accuracy: 93.41666666666667%
# Test: Loss 0.29421384930610656, Accuracy: 89.15%
# Epoch: 3
# Train: Loss: 0.15627271725485722, Accuracy: 94.13333333333334%
# Test: Loss 0.37351563572883606, Accuracy: 87.3%
# Epoch: 4
# Train: Loss: 0.14479849164684613, Accuracy: 94.375%
# Test: Loss 0.44926364421844484, Accuracy: 85.25%
# Epoch: 5
# Train: Loss: 0.156046601695319, Accuracy: 93.9%
# Test: Loss 0.30718631446361544, Accuracy: 89.4%
# Epoch: 6
# Train: Loss: 0.18299506222829223, Accuracy: 92.31666666666666%
# Test: Loss 0.32378103509545325, Accuracy: 88.7%
# Epoch: 7
# Train: Loss: 0.13426512780909736, Accuracy: 94.4%
# Test: Loss 0.47132750526070594, Accuracy: 87.8%
# Epoch: 8
# Train: Loss: 0.1399770366338392, Accuracy: 94.25%
# Test: Loss 0.6084241718053818, Accuracy: 85.5%
# Epoch: 9
# Train: Loss: 0.13994909602527816, Accuracy: 94.39166666666667%
# Test: Loss 0.44744106084108354, Accuracy: 87.85%
# Epoch: 10
# Train: Loss: 0.12743811880548794, Accuracy: 94.71666666666667%
# Test: Loss 0.3488043561577797, Accuracy: 89.25%
# Epoch: 11
# Train: Loss: 0.10486484326732655, Accuracy: 95.76666666666667%
# Test: Loss 0.481373493373394, Accuracy: 88.85%
# Epoch: 12
# Train: Loss: 0.09052109362867972, Accuracy: 96.475%
# Test: Loss 0.46746161878108977, Accuracy: 89.0%
# Epoch: 13
# Train: Loss: 0.10331826840216915, Accuracy: 95.69166666666666%
# Test: Loss 0.6344679370522499, Accuracy: 87.0%
# Epoch: 14
# Train: Loss: 0.09624877434689552, Accuracy: 96.34166666666667%
# Test: Loss 0.5470175564289093, Accuracy: 88.4%
# Epoch: 15
# Train: Loss: 0.096023196571817, Accuracy: 96.35833333333333%
# Test: Loss 0.762935857474804, Accuracy: 83.85%
# Epoch: 16
# Train: Loss: 0.09129296314592163, Accuracy: 96.24166666666666%
# Test: Loss 0.5124227792024613, Accuracy: 87.8%
# Epoch: 17
# Train: Loss: 0.09225328371394426, Accuracy: 96.50833333333334%
# Test: Loss 0.5287086620926857, Accuracy: 87.9%
# Epoch: 18
# Train: Loss: 0.11654492002756646, Accuracy: 95.49166666666666%
# Test: Loss 0.5230316877365112, Accuracy: 88.65%
# Epoch: 19
# Train: Loss: 0.10272025416682785, Accuracy: 95.975%
# Test: Loss 0.6889378190040588, Accuracy: 87.7%
# Epoch: 20
# Train: Loss: 0.1117024490221714, Accuracy: 95.55833333333334%
# Test: Loss 0.7174038097262383, Accuracy: 86.45%
# Epoch: 21
# Train: Loss: 0.0932846872950904, Accuracy: 96.36666666666666%
# Test: Loss 0.5453608632087708, Accuracy: 89.6%
# Epoch: 22
# Train: Loss: 0.07183510758914054, Accuracy: 97.1%
# Test: Loss 0.4902432426810265, Accuracy: 88.8%
# Epoch: 23
# Train: Loss: 0.04483548419472451, Accuracy: 98.36666666666666%
# Test: Loss 0.5566359013319016, Accuracy: 88.85%
# Epoch: 24
# Train: Loss: 0.03515158631101561, Accuracy: 98.63333333333334%
# Test: Loss 0.663787454366684, Accuracy: 89.05%
# Epoch: 25
# Train: Loss: 0.03996422878699377, Accuracy: 98.55%
# Test: Loss 0.7348947107791901, Accuracy: 88.3%
# Epoch: 26
# Train: Loss: 0.035004926038285096, Accuracy: 98.775%
# Test: Loss 0.6987110003829002, Accuracy: 88.15%
# Epoch: 27
# Train: Loss: 0.03698144746498049, Accuracy: 98.5%
# Test: Loss 0.6730388931930065, Accuracy: 88.2%
# Epoch: 28
# Train: Loss: 0.04040674137067981, Accuracy: 98.35833333333333%
# Test: Loss 0.5684591621160507, Accuracy: 87.85%
# Epoch: 29
# Train: Loss: 0.05062617810520654, Accuracy: 97.975%
# Test: Loss 0.6327258214354515, Accuracy: 86.35%
# Epoch: 30
# Train: Loss: 0.031910197978140785, Accuracy: 98.80833333333334%
# Test: Loss 0.710253880918026, Accuracy: 86.75%
# Epoch: 31
# Train: Loss: 0.025051573672196053, Accuracy: 98.94166666666666%
# Test: Loss 0.7988552659749985, Accuracy: 86.1%
# Epoch: 32
# Train: Loss: 0.026238940520367276, Accuracy: 98.94166666666666%
# Test: Loss 0.6986276417970657, Accuracy: 88.05%
# Epoch: 33
# Train: Loss: 0.023576280066239026, Accuracy: 99.1%
# Test: Loss 0.8112969264388085, Accuracy: 86.75%
# Epoch: 34
# Train: Loss: 0.02183210973647268, Accuracy: 99.2%
# Test: Loss 0.7016466677188873, Accuracy: 88.75%
# Epoch: 35
# Train: Loss: 0.0255875859700609, Accuracy: 99.01666666666667%
# Test: Loss 0.7545054614543915, Accuracy: 87.3%
# Epoch: 36
# Train: Loss: 0.02923378235718701, Accuracy: 98.94166666666666%
# Test: Loss 0.741127222776413, Accuracy: 87.9%
# Epoch: 37
# Train: Loss: 0.039885498920921234, Accuracy: 98.45%
# Test: Loss 0.7087638139724731, Accuracy: 87.75%
# Epoch: 38
# Train: Loss: 0.04656058664162022, Accuracy: 98.11666666666666%
# Test: Loss 0.6393929481506347, Accuracy: 88.5%
# Epoch: 39
# Train: Loss: 0.04326487386521573, Accuracy: 98.41666666666667%
# Test: Loss 0.5474580496549606, Accuracy: 88.75%
# Epoch: 40
# Train: Loss: 0.04477359561327224, Accuracy: 98.21666666666667%
# Test: Loss 0.6571514531970024, Accuracy: 87.7%
# Epoch: 41
# Train: Loss: 0.04468109911589029, Accuracy: 98.44166666666666%
# Test: Loss 0.7903707519173622, Accuracy: 88.1%
# Epoch: 42
# Train: Loss: 0.049287169817641065, Accuracy: 98.15833333333333%
# Test: Loss 0.9870873555541039, Accuracy: 87.65%
# Epoch: 43
# Train: Loss: 0.04724436477845302, Accuracy: 98.225%
# Test: Loss 1.5173532038927078, Accuracy: 85.15%
# Epoch: 44
# Train: Loss: 0.04761295114355259, Accuracy: 98.2%
# Test: Loss 1.0287679195404054, Accuracy: 86.5%
# Epoch: 45
# Train: Loss: 0.06584249335537606, Accuracy: 97.74166666666666%
# Test: Loss 0.9543830722570419, Accuracy: 87.7%
# Epoch: 46
# Train: Loss: 0.07163527486797344, Accuracy: 97.55%
# Test: Loss 1.0792314469814301, Accuracy: 87.2%
# Epoch: 47
# Train: Loss: 0.06311156894080341, Accuracy: 97.725%
# Test: Loss 0.752001017332077, Accuracy: 89.55%
# Epoch: 48
# Train: Loss: 0.035977641446030856, Accuracy: 98.55833333333334%
# Test: Loss 0.7492598325014115, Accuracy: 87.15%
# Epoch: 49
# Train: Loss: 0.01125273313737125, Accuracy: 99.575%
# Test: Loss 0.8119052588939667, Accuracy: 88.2%
# Epoch: 50
# Train: Loss: 0.0049839952138730345, Accuracy: 99.83333333333333%
# Test: Loss 0.9835003823041916, Accuracy: 88.1%
# Epoch: 51
# Train: Loss: 0.005589806303608687, Accuracy: 99.825%
# Test: Loss 1.0450164675712585, Accuracy: 88.25%
# Epoch: 52
# Train: Loss: 0.003890845501897881, Accuracy: 99.86666666666666%
# Test: Loss 1.1877944499254227, Accuracy: 88.65%
# Epoch: 53
# Train: Loss: 0.015872913971876793, Accuracy: 99.43333333333334%
# Test: Loss 0.888996696472168, Accuracy: 88.0%
# Epoch: 54
# Train: Loss: 0.02472631644965683, Accuracy: 99.05%
# Test: Loss 0.6741733342409134, Accuracy: 87.5%
# Epoch: 55
# Train: Loss: 0.013834286419175139, Accuracy: 99.54166666666667%
# Test: Loss 0.8161614045500756, Accuracy: 87.55%
# Epoch: 56
# Train: Loss: 0.011941150827260572, Accuracy: 99.58333333333333%
# Test: Loss 1.013277253508568, Accuracy: 87.3%
# Epoch: 57
# Train: Loss: 0.010631185445163283, Accuracy: 99.58333333333333%
# Test: Loss 1.0636801093816757, Accuracy: 87.65%
# Epoch: 58
# Train: Loss: 0.01421300351479052, Accuracy: 99.54166666666667%
# Test: Loss 0.9175702422857285, Accuracy: 88.0%
# Epoch: 59
# Train: Loss: 0.00892936886765104, Accuracy: 99.7%
# Test: Loss 1.0302784264087677, Accuracy: 88.8%
# Epoch: 60
# Train: Loss: 0.017900010098552837, Accuracy: 99.38333333333334%
# Test: Loss 1.0103342592716218, Accuracy: 86.45%
# Epoch: 61
# Train: Loss: 0.011696614317224885, Accuracy: 99.525%
# Test: Loss 0.9360542073845863, Accuracy: 87.95%
# Epoch: 62
# Train: Loss: 0.007378634743023819, Accuracy: 99.75%
# Test: Loss 0.9436214417219162, Accuracy: 88.15%
# Epoch: 63
# Train: Loss: 0.010228275146861658, Accuracy: 99.66666666666667%
# Test: Loss 1.0118416845798492, Accuracy: 87.1%
# Epoch: 64
# Train: Loss: 0.006937556963748648, Accuracy: 99.73333333333333%
# Test: Loss 1.0876113682985307, Accuracy: 88.15%
# Epoch: 65
# Train: Loss: 0.011696175756666587, Accuracy: 99.6%
# Test: Loss 1.1065200984477996, Accuracy: 87.95%
# Epoch: 66
# Train: Loss: 0.01606536440273582, Accuracy: 99.425%
# Test: Loss 1.0123634964227677, Accuracy: 87.85%
# Epoch: 67
# Train: Loss: 0.020815555767452074, Accuracy: 99.16666666666667%
# Test: Loss 0.854662598669529, Accuracy: 87.75%
# Epoch: 68
# Train: Loss: 0.009266317896602535, Accuracy: 99.7%
# Test: Loss 0.9889384388923645, Accuracy: 87.15%
# Epoch: 69
# Train: Loss: 0.012403040832214173, Accuracy: 99.525%
# Test: Loss 1.02786525785923, Accuracy: 88.3%
# Epoch: 70
# Train: Loss: 0.015508131401657011, Accuracy: 99.34166666666667%
# Test: Loss 0.9817522972822189, Accuracy: 87.8%
# Epoch: 71
# Train: Loss: 0.01486128711233808, Accuracy: 99.53333333333333%
# Test: Loss 1.0484277665615083, Accuracy: 86.9%
# Epoch: 72
# Train: Loss: 0.011513039217758585, Accuracy: 99.59166666666667%
# Test: Loss 1.0271191865205764, Accuracy: 86.55%
# Epoch: 73
# Train: Loss: 0.009946004838396524, Accuracy: 99.61666666666666%
# Test: Loss 1.088421669602394, Accuracy: 88.6%
# Epoch: 74
# Train: Loss: 0.010229176832945086, Accuracy: 99.7%
# Test: Loss 1.0200011014938355, Accuracy: 87.65%
# Epoch: 75
# Train: Loss: 0.01087176527222861, Accuracy: 99.65%
# Test: Loss 1.252960640192032, Accuracy: 87.45%
# Epoch: 76
# Train: Loss: 0.01665036933494169, Accuracy: 99.4%
# Test: Loss 0.8200761869549751, Accuracy: 87.55%
# Epoch: 77
# Train: Loss: 0.010608570654828025, Accuracy: 99.61666666666666%
# Test: Loss 1.095558062195778, Accuracy: 87.6%
# Epoch: 78
# Train: Loss: 0.022177678983158935, Accuracy: 99.20833333333333%
# Test: Loss 1.0399095326662064, Accuracy: 87.9%
# Epoch: 79
# Train: Loss: 0.010449007462890828, Accuracy: 99.625%
# Test: Loss 1.0178351163864137, Accuracy: 88.05%
# Epoch: 80
# Train: Loss: 0.017229666829052803, Accuracy: 99.41666666666667%
# Test: Loss 1.3119296193122865, Accuracy: 88.15%
# Epoch: 81
# Train: Loss: 0.01452263186086687, Accuracy: 99.475%
# Test: Loss 1.0664181292057038, Accuracy: 87.2%
# Epoch: 82
# Train: Loss: 0.009906949168665354, Accuracy: 99.63333333333334%
# Test: Loss 0.985579988360405, Accuracy: 89.05%
# Epoch: 83
# Train: Loss: 0.012013195016425015, Accuracy: 99.58333333333333%
# Test: Loss 1.0971413463354112, Accuracy: 87.4%
# Epoch: 84
# Train: Loss: 0.012195014093110027, Accuracy: 99.64166666666667%
# Test: Loss 1.1315860152244568, Accuracy: 88.4%
# Epoch: 85
# Train: Loss: 0.01714858889607361, Accuracy: 99.4%
# Test: Loss 1.0377760708332062, Accuracy: 87.55%
# Epoch: 86
# Train: Loss: 0.025103212771894808, Accuracy: 99.15833333333333%
# Test: Loss 1.072133269906044, Accuracy: 87.8%
# Epoch: 87
# Train: Loss: 0.025857575818129894, Accuracy: 99.1%
# Test: Loss 1.1391189455986024, Accuracy: 87.25%
# Epoch: 88
# Train: Loss: 0.01303910169796533, Accuracy: 99.575%
# Test: Loss 1.1445498615503311, Accuracy: 87.85%
# Epoch: 89
# Train: Loss: 0.0061679708566771295, Accuracy: 99.81666666666666%
# Test: Loss 1.1450483858585359, Accuracy: 88.0%
# Epoch: 90
# Train: Loss: 0.006846655681935469, Accuracy: 99.81666666666666%
# Test: Loss 1.0670770972967147, Accuracy: 88.35%
# Epoch: 91
# Train: Loss: 0.007996328085027926, Accuracy: 99.69166666666666%
# Test: Loss 1.1358582675457, Accuracy: 88.55%
# Epoch: 92
# Train: Loss: 0.008508061100868266, Accuracy: 99.73333333333333%
# Test: Loss 1.1731189906597137, Accuracy: 88.6%
# Epoch: 93
# Train: Loss: 0.0047436402301855194, Accuracy: 99.825%
# Test: Loss 1.205089047551155, Accuracy: 88.7%
# Epoch: 94
# Train: Loss: 0.009368630322660465, Accuracy: 99.64166666666667%
# Test: Loss 1.2218054980039597, Accuracy: 88.05%
# Epoch: 95
# Train: Loss: 0.009351511324590925, Accuracy: 99.64166666666667%
# Test: Loss 1.1472535461187363, Accuracy: 87.95%
# Epoch: 96
# Train: Loss: 0.012030626926555972, Accuracy: 99.54166666666667%
# Test: Loss 1.0328053116798401, Accuracy: 88.65%
# Epoch: 97
# Train: Loss: 0.013826610321575571, Accuracy: 99.55%
# Test: Loss 1.1575607419013978, Accuracy: 87.8%
# Epoch: 98
# Train: Loss: 0.013438471129878357, Accuracy: 99.59166666666667%
# Test: Loss 1.4988238334655761, Accuracy: 86.8%
# Epoch: 99
# Train: Loss: 0.0257102468964149, Accuracy: 99.075%
# Test: Loss 0.9141338378190994, Accuracy: 88.3%
# Epoch: 100
# Train: Loss: 0.011777157933245993, Accuracy: 99.60833333333333%
# Test: Loss 0.9920578092336655, Accuracy: 88.5%
# Extra Model #1
# Epoch: 1
# Train: Loss: 0.23373234652810626, Accuracy: 91.47777777777777%
# Test: Loss 0.33747886021931967, Accuracy: 88.86666666666666%
# Epoch: 2
# Train: Loss: 0.21673070308234957, Accuracy: 92.05%
# Test: Loss 0.3713253433505694, Accuracy: 87.73333333333333%
# Epoch: 3
# Train: Loss: 0.20182880779935253, Accuracy: 92.64444444444445%
# Test: Loss 0.327571502327919, Accuracy: 89.33333333333333%
# Epoch: 4
# Train: Loss: 0.20390452250010438, Accuracy: 92.53888888888889%
# Test: Loss 0.3315235321720441, Accuracy: 89.0%
# Epoch: 5
# Train: Loss: 0.2095280601332585, Accuracy: 92.13333333333334%
# Test: Loss 0.3728370890021324, Accuracy: 87.7%
# Epoch: 6
# Train: Loss: 0.20210023245049846, Accuracy: 92.63333333333334%
# Test: Loss 0.4694892173012098, Accuracy: 84.56666666666666%
# Epoch: 7
# Train: Loss: 0.19231385336154036, Accuracy: 92.98333333333333%
# Test: Loss 0.422347088654836, Accuracy: 86.23333333333333%
# Epoch: 8
# Train: Loss: 0.18684611736486356, Accuracy: 93.26666666666667%
# Test: Loss 0.44849707384904225, Accuracy: 86.33333333333333%
# Epoch: 9
# Train: Loss: 0.17423558411084944, Accuracy: 93.7%
# Test: Loss 0.4356933106978734, Accuracy: 87.43333333333334%
# Epoch: 10
# Train: Loss: 0.15579331039140623, Accuracy: 94.28333333333333%
# Test: Loss 0.4880060970783234, Accuracy: 86.16666666666667%
# Epoch: 11
# Train: Loss: 0.14246662101811833, Accuracy: 94.92777777777778%
# Test: Loss 0.4055837089816729, Accuracy: 88.16666666666667%
# Epoch: 12
# Train: Loss: 0.12480920787072844, Accuracy: 95.59444444444445%
# Test: Loss 0.39689459800720217, Accuracy: 89.06666666666666%
# Epoch: 13
# Train: Loss: 0.10901760072964761, Accuracy: 96.11666666666666%
# Test: Loss 0.46494584331909816, Accuracy: 88.56666666666666%
# Epoch: 14
# Train: Loss: 0.1190783006656501, Accuracy: 95.80555555555556%
# Test: Loss 0.5508063266674678, Accuracy: 86.06666666666666%
# Epoch: 15
# Train: Loss: 0.13770739604822463, Accuracy: 94.88888888888889%
# Test: Loss 0.46960733632246654, Accuracy: 87.76666666666667%
# Epoch: 16
# Train: Loss: 0.14611072610649797, Accuracy: 94.4%
# Test: Loss 0.39789287745952606, Accuracy: 88.93333333333334%
# Epoch: 17
# Train: Loss: 0.1270855377221273, Accuracy: 95.2%
# Test: Loss 0.4428345839182536, Accuracy: 88.7%
# Epoch: 18
# Train: Loss: 0.12236070938201414, Accuracy: 95.32222222222222%
# Test: Loss 0.5003840213020643, Accuracy: 87.53333333333333%
# Epoch: 19
# Train: Loss: 0.12667460666141575, Accuracy: 95.06666666666666%
# Test: Loss 0.5257169579466184, Accuracy: 87.33333333333333%
# Epoch: 20
# Train: Loss: 0.1317809305464228, Accuracy: 95.22222222222223%
# Test: Loss 0.4635765229662259, Accuracy: 87.93333333333334%
# Epoch: 21
# Train: Loss: 0.09680683302382628, Accuracy: 96.71111111111111%
# Test: Loss 0.49148567269245785, Accuracy: 88.13333333333334%
# Epoch: 22
# Train: Loss: 0.07980590339543091, Accuracy: 97.22222222222223%
# Test: Loss 0.5803671985864639, Accuracy: 87.9%
# Epoch: 23
# Train: Loss: 0.08023491961778038, Accuracy: 97.18888888888888%
# Test: Loss 0.6492223779360453, Accuracy: 86.96666666666667%
# Epoch: 24
# Train: Loss: 0.07256350501233505, Accuracy: 97.39444444444445%
# Test: Loss 0.6447595556577047, Accuracy: 87.46666666666667%
# Epoch: 25
# Train: Loss: 0.07532828083365328, Accuracy: 97.11666666666666%
# Test: Loss 0.6582665850718816, Accuracy: 88.6%
# Epoch: 26
# Train: Loss: 0.08047203964346814, Accuracy: 97.00555555555556%
# Test: Loss 0.5936825300256411, Accuracy: 88.73333333333333%
# Epoch: 27
# Train: Loss: 0.09049515476605545, Accuracy: 96.63333333333334%
# Test: Loss 0.5884320040543874, Accuracy: 86.93333333333334%
# Epoch: 28
# Train: Loss: 0.07740768626746204, Accuracy: 97.15555555555555%
# Test: Loss 0.6588683038949966, Accuracy: 87.03333333333333%
# Epoch: 29
# Train: Loss: 0.07498099303856078, Accuracy: 97.15555555555555%
# Test: Loss 0.8363600462675095, Accuracy: 84.8%
# Epoch: 30
# Train: Loss: 0.0732530243617172, Accuracy: 97.26666666666667%
# Test: Loss 1.000646303097407, Accuracy: 82.66666666666667%
# Epoch: 31
# Train: Loss: 0.07032073143248757, Accuracy: 97.32222222222222%
# Test: Loss 1.03077077070872, Accuracy: 83.2%
# Epoch: 32
# Train: Loss: 0.06107601950255533, Accuracy: 97.63888888888889%
# Test: Loss 0.8752179036537806, Accuracy: 85.06666666666666%
# Epoch: 33
# Train: Loss: 0.06315873425919563, Accuracy: 97.61666666666666%
# Test: Loss 0.9453271597623825, Accuracy: 84.56666666666666%
# Epoch: 34
# Train: Loss: 0.06274587244907807, Accuracy: 97.53333333333333%
# Test: Loss 0.654086614648501, Accuracy: 88.73333333333333%
# Epoch: 35
# Train: Loss: 0.07097787638194859, Accuracy: 97.24444444444444%
# Test: Loss 0.7152187575896581, Accuracy: 87.06666666666666%
# Epoch: 36
# Train: Loss: 0.057580885112596056, Accuracy: 97.98333333333333%
# Test: Loss 0.6844242975115776, Accuracy: 87.73333333333333%
# Epoch: 37
# Train: Loss: 0.0441721977885916, Accuracy: 98.33888888888889%
# Test: Loss 0.7108386640747388, Accuracy: 88.33333333333333%
# Epoch: 38
# Train: Loss: 0.03396707121024115, Accuracy: 98.77777777777777%
# Test: Loss 0.7508321583271027, Accuracy: 88.4%
# Epoch: 39
# Train: Loss: 0.040436891507447906, Accuracy: 98.48333333333333%
# Test: Loss 0.8397077992558479, Accuracy: 87.53333333333333%
# Epoch: 40
# Train: Loss: 0.05396508156360748, Accuracy: 98.09444444444445%
# Test: Loss 0.8311807801326115, Accuracy: 86.86666666666666%
# Epoch: 41
# Train: Loss: 0.047535854464189876, Accuracy: 98.31111111111112%
# Test: Loss 0.7546913266181946, Accuracy: 88.36666666666666%
# Epoch: 42
# Train: Loss: 0.041927458724886596, Accuracy: 98.51666666666667%
# Test: Loss 0.8380769600470861, Accuracy: 87.86666666666666%
# Epoch: 43
# Train: Loss: 0.03859460476992859, Accuracy: 98.57777777777778%
# Test: Loss 0.8093295474847158, Accuracy: 87.26666666666667%
# Epoch: 44
# Train: Loss: 0.028777144361649538, Accuracy: 99.06111111111112%
# Test: Loss 0.8253730316956838, Accuracy: 88.16666666666667%
# Epoch: 45
# Train: Loss: 0.029893088477223904, Accuracy: 98.83888888888889%
# Test: Loss 0.8612444281578064, Accuracy: 88.16666666666667%
# Epoch: 46
# Train: Loss: 0.03641378371846966, Accuracy: 98.56666666666666%
# Test: Loss 0.9467368453741074, Accuracy: 87.26666666666667%
# Epoch: 47
# Train: Loss: 0.02656061180233438, Accuracy: 98.9888888888889%
# Test: Loss 0.8664176732301712, Accuracy: 88.53333333333333%
# Epoch: 48
# Train: Loss: 0.02813733172046745, Accuracy: 98.97777777777777%
# Test: Loss 0.9383862137794494, Accuracy: 88.0%
# Epoch: 49
# Train: Loss: 0.03155813496883234, Accuracy: 98.82777777777778%
# Test: Loss 0.920478825767835, Accuracy: 88.06666666666666%
# Epoch: 50
# Train: Loss: 0.03103721805544208, Accuracy: 98.93333333333334%
# Test: Loss 0.9278630912303925, Accuracy: 87.3%
# Epoch: 51
# Train: Loss: 0.028047256195633155, Accuracy: 99.01666666666667%
# Test: Loss 0.9056190848350525, Accuracy: 88.5%
# Epoch: 52
# Train: Loss: 0.03822616023891088, Accuracy: 98.63333333333334%
# Test: Loss 0.9747091909249623, Accuracy: 86.6%
# Epoch: 53
# Train: Loss: 0.043318611612388244, Accuracy: 98.57222222222222%
# Test: Loss 0.9109393080075582, Accuracy: 86.96666666666667%
# Epoch: 54
# Train: Loss: 0.029339359569389167, Accuracy: 98.88888888888889%
# Test: Loss 1.0158011088768641, Accuracy: 86.8%
# Epoch: 55
# Train: Loss: 0.03409089874427688, Accuracy: 98.7388888888889%
# Test: Loss 0.9414542635281881, Accuracy: 87.83333333333333%
# Epoch: 56
# Train: Loss: 0.03565080761553771, Accuracy: 98.65%
# Test: Loss 0.912913982073466, Accuracy: 88.06666666666666%
# Epoch: 57
# Train: Loss: 0.031767113150757115, Accuracy: 98.77777777777777%
# Test: Loss 0.9102207481861114, Accuracy: 88.53333333333333%
# Epoch: 58
# Train: Loss: 0.031082716181440952, Accuracy: 98.81111111111112%
# Test: Loss 0.8935160557428996, Accuracy: 88.36666666666666%
# Epoch: 59
# Train: Loss: 0.03345671375411459, Accuracy: 98.7388888888889%
# Test: Loss 0.8677101224660874, Accuracy: 88.36666666666666%
# Epoch: 60
# Train: Loss: 0.02267385897381852, Accuracy: 99.16111111111111%
# Test: Loss 0.9778839617967605, Accuracy: 88.16666666666667%
# Epoch: 61
# Train: Loss: 0.02832171929929043, Accuracy: 98.98333333333333%
# Test: Loss 1.031247123082479, Accuracy: 87.06666666666666%
# Epoch: 62
# Train: Loss: 0.01987595597214143, Accuracy: 99.27777777777777%
# Test: Loss 1.0043911149104436, Accuracy: 87.86666666666666%
# Epoch: 63
# Train: Loss: 0.03166246247451959, Accuracy: 98.93888888888888%
# Test: Loss 1.0497274696826935, Accuracy: 87.1%
# Epoch: 64
# Train: Loss: 0.020394906865516937, Accuracy: 99.21111111111111%
# Test: Loss 0.9635426153739294, Accuracy: 88.23333333333333%
# Epoch: 65
# Train: Loss: 0.025703262526723038, Accuracy: 99.01666666666667%
# Test: Loss 1.1472028175989786, Accuracy: 86.9%
# Epoch: 66
# Train: Loss: 0.02539382857123403, Accuracy: 99.01666666666667%
# Test: Loss 1.0284737835327784, Accuracy: 87.56666666666666%
# Epoch: 67
# Train: Loss: 0.022570668314518923, Accuracy: 99.13333333333334%
# Test: Loss 1.053438518444697, Accuracy: 87.46666666666667%
# Epoch: 68
# Train: Loss: 0.01930132667726462, Accuracy: 99.32777777777778%
# Test: Loss 1.094047447045644, Accuracy: 88.1%
# Epoch: 69
# Train: Loss: 0.022259815648916024, Accuracy: 99.30555555555556%
# Test: Loss 0.9979291061560313, Accuracy: 88.9%
# Epoch: 70
# Train: Loss: 0.02906891758563385, Accuracy: 99.01666666666667%
# Test: Loss 1.0012853542963664, Accuracy: 87.6%
# Epoch: 71
# Train: Loss: 0.016406292002648114, Accuracy: 99.46666666666667%
# Test: Loss 1.0474000036716462, Accuracy: 87.66666666666667%
# Epoch: 72
# Train: Loss: 0.019811986032841053, Accuracy: 99.24444444444444%
# Test: Loss 1.2472058296203614, Accuracy: 86.76666666666667%
# Epoch: 73
# Train: Loss: 0.019560492531147448, Accuracy: 99.40555555555555%
# Test: Loss 1.1294536689917247, Accuracy: 87.3%
# Epoch: 74
# Train: Loss: 0.02218225485945974, Accuracy: 99.25%
# Test: Loss 1.0820555369059244, Accuracy: 87.03333333333333%
# Epoch: 75
# Train: Loss: 0.028147711230364317, Accuracy: 98.99444444444444%
# Test: Loss 0.9920017143090566, Accuracy: 88.33333333333333%
# Epoch: 76
# Train: Loss: 0.024477883619126967, Accuracy: 99.17222222222222%
# Test: Loss 1.0112960080305735, Accuracy: 88.66666666666667%
# Epoch: 77
# Train: Loss: 0.01659684883470618, Accuracy: 99.37777777777778%
# Test: Loss 1.0876492470502854, Accuracy: 88.16666666666667%
# Epoch: 78
# Train: Loss: 0.023668973856062318, Accuracy: 99.16666666666667%
# Test: Loss 1.0733813146750133, Accuracy: 87.63333333333334%
# Epoch: 79
# Train: Loss: 0.01962937506228223, Accuracy: 99.31111111111112%
# Test: Loss 1.119268137216568, Accuracy: 87.56666666666666%
# Epoch: 80
# Train: Loss: 0.021601103667409107, Accuracy: 99.27777777777777%
# Test: Loss 1.076067398985227, Accuracy: 87.8%
# Epoch: 81
# Train: Loss: 0.021322499616993205, Accuracy: 99.18888888888888%
# Test: Loss 1.1833417455355326, Accuracy: 87.73333333333333%
# Epoch: 82
# Train: Loss: 0.021636793983472874, Accuracy: 99.18888888888888%
# Test: Loss 1.0862118363380433, Accuracy: 87.7%
# Epoch: 83
# Train: Loss: 0.014971877630321413, Accuracy: 99.44444444444444%
# Test: Loss 1.1375537355740866, Accuracy: 88.86666666666666%
# Epoch: 84
# Train: Loss: 0.0271863166570256, Accuracy: 99.15%
# Test: Loss 1.1468922168016433, Accuracy: 87.73333333333333%
# Epoch: 85
# Train: Loss: 0.025231691849168986, Accuracy: 99.11666666666666%
# Test: Loss 1.0720042447249094, Accuracy: 87.76666666666667%
# Epoch: 86
# Train: Loss: 0.02338462073033346, Accuracy: 99.22222222222223%
# Test: Loss 1.1010934034983317, Accuracy: 86.86666666666666%
# Epoch: 87
# Train: Loss: 0.018086095025602038, Accuracy: 99.40555555555555%
# Test: Loss 1.0608803411324819, Accuracy: 88.43333333333334%
# Epoch: 88
# Train: Loss: 0.018052639915751772, Accuracy: 99.43333333333334%
# Test: Loss 1.001748808224996, Accuracy: 88.2%
# Epoch: 89
# Train: Loss: 0.020656424225954755, Accuracy: 99.3%
# Test: Loss 1.2001843293507894, Accuracy: 86.96666666666667%
# Epoch: 90
# Train: Loss: 0.02245849589311951, Accuracy: 99.21111111111111%
# Test: Loss 1.0625765492518744, Accuracy: 87.96666666666667%
# Epoch: 91
# Train: Loss: 0.02444009629980428, Accuracy: 99.22222222222223%
# Test: Loss 1.0931439757347108, Accuracy: 88.3%
# Epoch: 92
# Train: Loss: 0.025705949864964675, Accuracy: 99.12222222222222%
# Test: Loss 1.1591893037160237, Accuracy: 87.16666666666667%
# Epoch: 93
# Train: Loss: 0.0190095245828464, Accuracy: 99.3%
# Test: Loss 1.2109903852144877, Accuracy: 86.86666666666666%
# Epoch: 94
# Train: Loss: 0.018924474769341434, Accuracy: 99.34444444444445%
# Test: Loss 1.1803820530573528, Accuracy: 87.46666666666667%
# Epoch: 95
# Train: Loss: 0.026736739570979908, Accuracy: 99.07777777777778%
# Test: Loss 1.0716969569524128, Accuracy: 88.63333333333334%
# Epoch: 96
# Train: Loss: 0.0221259789054683, Accuracy: 99.21111111111111%
# Test: Loss 1.1167824248472848, Accuracy: 87.7%
# Epoch: 97
# Train: Loss: 0.023125034623323396, Accuracy: 99.27222222222223%
# Test: Loss 1.1098209599653879, Accuracy: 87.73333333333333%
# Epoch: 98
# Train: Loss: 0.011910469431960438, Accuracy: 99.58333333333333%
# Test: Loss 1.2458723386128743, Accuracy: 87.03333333333333%
# Epoch: 99
# Train: Loss: 0.019869768166184562, Accuracy: 99.27222222222223%
# Test: Loss 1.119816392660141, Accuracy: 87.8%
# Epoch: 100
# Train: Loss: 0.020044019729539286, Accuracy: 99.31111111111112%
# Test: Loss 1.1063535928726196, Accuracy: 87.83333333333333%
# Extra Model #2
# Epoch: 1
# Train: Loss: 0.2266114872569839, Accuracy: 91.46666666666667%
# Test: Loss 0.3317827131599188, Accuracy: 88.65%
# Epoch: 2
# Train: Loss: 0.21454234458506108, Accuracy: 91.82083333333334%
# Test: Loss 0.3308454729616642, Accuracy: 89.0%
# Epoch: 3
# Train: Loss: 0.21793045581628878, Accuracy: 91.77916666666667%
# Test: Loss 0.33403574414551257, Accuracy: 88.625%
# Epoch: 4
# Train: Loss: 0.20154477826630077, Accuracy: 92.4125%
# Test: Loss 0.3239264003932476, Accuracy: 88.975%
# Epoch: 5
# Train: Loss: 0.18713827089716992, Accuracy: 92.9625%
# Test: Loss 0.3606269996613264, Accuracy: 88.2%
# Epoch: 6
# Train: Loss: 0.18042524453873435, Accuracy: 93.20416666666667%
# Test: Loss 0.40758947618305685, Accuracy: 87.275%
# Epoch: 7
# Train: Loss: 0.17378513569322726, Accuracy: 93.45%
# Test: Loss 0.39078742191195487, Accuracy: 87.875%
# Epoch: 8
# Train: Loss: 0.17601987913561365, Accuracy: 93.22916666666667%
# Test: Loss 0.3667801201343536, Accuracy: 88.5%
# Epoch: 9
# Train: Loss: 0.1742583184192578, Accuracy: 93.4125%
# Test: Loss 0.47208198308944704, Accuracy: 86.375%
# Epoch: 10
# Train: Loss: 0.15296727092936635, Accuracy: 94.22916666666667%
# Test: Loss 0.4795858975499868, Accuracy: 87.175%
# Epoch: 11
# Train: Loss: 0.1453921367879957, Accuracy: 94.59166666666667%
# Test: Loss 0.5601931840181351, Accuracy: 86.125%
# Epoch: 12
# Train: Loss: 0.1427734861616045, Accuracy: 94.52083333333333%
# Test: Loss 0.5148277040570974, Accuracy: 87.025%
# Epoch: 13
# Train: Loss: 0.14877001699060202, Accuracy: 94.2%
# Test: Loss 0.5150634679943323, Accuracy: 87.075%
# Epoch: 14
# Train: Loss: 0.12994306599721311, Accuracy: 94.97916666666667%
# Test: Loss 0.5792486481368542, Accuracy: 86.525%
# Epoch: 15
# Train: Loss: 0.11143594030290842, Accuracy: 95.775%
# Test: Loss 0.5764682129025459, Accuracy: 87.55%
# Epoch: 16
# Train: Loss: 0.10716869228829941, Accuracy: 95.95416666666667%
# Test: Loss 0.5552977856248618, Accuracy: 87.85%
# Epoch: 17
# Train: Loss: 0.11216490219036739, Accuracy: 95.66666666666667%
# Test: Loss 0.5105229176580905, Accuracy: 87.85%
# Epoch: 18
# Train: Loss: 0.1178586540898929, Accuracy: 95.5375%
# Test: Loss 0.5068459745496512, Accuracy: 87.0%
# Epoch: 19
# Train: Loss: 0.10500963899151733, Accuracy: 96.02916666666667%
# Test: Loss 0.6110851939767599, Accuracy: 85.6%
# Epoch: 20
# Train: Loss: 0.09349023865070194, Accuracy: 96.49583333333334%
# Test: Loss 0.6947199977934361, Accuracy: 85.325%
# Epoch: 21
# Train: Loss: 0.0910632969927974, Accuracy: 96.58333333333333%
# Test: Loss 0.67620849609375, Accuracy: 86.3%
# Epoch: 22
# Train: Loss: 0.08670158226353426, Accuracy: 96.73333333333333%
# Test: Loss 0.7108484920114279, Accuracy: 86.375%
# Epoch: 23
# Train: Loss: 0.09741594673056776, Accuracy: 96.40833333333333%
# Test: Loss 0.7176479652523995, Accuracy: 86.425%
# Epoch: 24
# Train: Loss: 0.10248666498810052, Accuracy: 96.25416666666666%
# Test: Loss 0.6717011969536543, Accuracy: 87.125%
# Epoch: 25
# Train: Loss: 0.08672039520073062, Accuracy: 96.5375%
# Test: Loss 0.6522488608956337, Accuracy: 87.475%
# Epoch: 26
# Train: Loss: 0.07138557085224116, Accuracy: 97.35%
# Test: Loss 0.7037758298218251, Accuracy: 87.85%
# Epoch: 27
# Train: Loss: 0.06383097575744615, Accuracy: 97.71666666666667%
# Test: Loss 0.7804034195840359, Accuracy: 87.25%
# Epoch: 28
# Train: Loss: 0.05368820051662624, Accuracy: 97.90833333333333%
# Test: Loss 0.8396546185016632, Accuracy: 86.5%
# Epoch: 29
# Train: Loss: 0.06743061843056543, Accuracy: 97.525%
# Test: Loss 0.7549488622695207, Accuracy: 87.425%
# Epoch: 30
# Train: Loss: 0.06174253509185898, Accuracy: 97.57083333333334%
# Test: Loss 0.7614787846803666, Accuracy: 87.9%
# Epoch: 31
# Train: Loss: 0.061459560121875256, Accuracy: 97.57916666666667%
# Test: Loss 0.7979028679430484, Accuracy: 87.35%
# Epoch: 32
# Train: Loss: 0.06347079121915158, Accuracy: 97.56666666666666%
# Test: Loss 0.763186364620924, Accuracy: 87.225%
# Epoch: 33
# Train: Loss: 0.0663333526366235, Accuracy: 97.43333333333334%
# Test: Loss 0.8221039816737175, Accuracy: 86.9%
# Epoch: 34
# Train: Loss: 0.05870892320720789, Accuracy: 97.74166666666666%
# Test: Loss 0.8004851713776588, Accuracy: 87.525%
# Epoch: 35
# Train: Loss: 0.05382340368911779, Accuracy: 97.94583333333334%
# Test: Loss 0.8352283217012882, Accuracy: 87.275%
# Epoch: 36
# Train: Loss: 0.05534604680821455, Accuracy: 97.9625%
# Test: Loss 0.8569736339151859, Accuracy: 86.875%
# Epoch: 37
# Train: Loss: 0.05722390301525593, Accuracy: 97.91666666666667%
# Test: Loss 0.8324607286602259, Accuracy: 86.925%
# Epoch: 38
# Train: Loss: 0.052228488079466236, Accuracy: 98.0625%
# Test: Loss 0.927752310782671, Accuracy: 86.4%
# Epoch: 39
# Train: Loss: 0.04892149866209365, Accuracy: 98.19166666666666%
# Test: Loss 0.9518665991723537, Accuracy: 85.525%
# Epoch: 40
# Train: Loss: 0.04877061488320275, Accuracy: 98.23333333333333%
# Test: Loss 0.9621189184486866, Accuracy: 86.125%
# Epoch: 41
# Train: Loss: 0.03835727111484933, Accuracy: 98.59583333333333%
# Test: Loss 1.0838888458907605, Accuracy: 86.075%
# Epoch: 42
# Train: Loss: 0.046897466539909755, Accuracy: 98.29583333333333%
# Test: Loss 0.8898303773254156, Accuracy: 87.275%
# Epoch: 43
# Train: Loss: 0.04087298473896226, Accuracy: 98.56666666666666%
# Test: Loss 0.9517724629491567, Accuracy: 87.45%
# Epoch: 44
# Train: Loss: 0.04058730789402034, Accuracy: 98.52916666666667%
# Test: Loss 0.9176635306328536, Accuracy: 87.625%
# Epoch: 45
# Train: Loss: 0.04774373364465039, Accuracy: 98.25%
# Test: Loss 0.9778678379952908, Accuracy: 86.65%
# Epoch: 46
# Train: Loss: 0.033467617180819316, Accuracy: 98.78333333333333%
# Test: Loss 1.064474444836378, Accuracy: 87.65%
# Epoch: 47
# Train: Loss: 0.03563238573060516, Accuracy: 98.70833333333333%
# Test: Loss 1.0744012631475925, Accuracy: 87.075%
# Epoch: 48
# Train: Loss: 0.03309727402617379, Accuracy: 98.77916666666667%
# Test: Loss 1.0298858165740967, Accuracy: 87.4%
# Epoch: 49
# Train: Loss: 0.04372281317337183, Accuracy: 98.46666666666667%
# Test: Loss 0.9954531602561474, Accuracy: 87.4%
# Epoch: 50
# Train: Loss: 0.03824158142742817, Accuracy: 98.6375%
# Test: Loss 1.0788815677165986, Accuracy: 86.875%
# Epoch: 51
# Train: Loss: 0.034900871035157856, Accuracy: 98.8%
# Test: Loss 1.0238142017275096, Accuracy: 87.625%
# Epoch: 52
# Train: Loss: 0.030512607975833817, Accuracy: 98.90833333333333%
# Test: Loss 1.0825316332280637, Accuracy: 87.575%
# Epoch: 53
# Train: Loss: 0.046153163104948665, Accuracy: 98.39583333333333%
# Test: Loss 1.0005728013813495, Accuracy: 86.85%
# Epoch: 54
# Train: Loss: 0.03765397880003244, Accuracy: 98.64166666666667%
# Test: Loss 1.0235004357993602, Accuracy: 87.65%
# Epoch: 55
# Train: Loss: 0.03232974546566159, Accuracy: 98.8375%
# Test: Loss 1.0698951989412309, Accuracy: 87.35%
# Epoch: 56
# Train: Loss: 0.03523518825386418, Accuracy: 98.68333333333334%
# Test: Loss 1.0309582352638245, Accuracy: 87.0%
# Epoch: 57
# Train: Loss: 0.03263218510619481, Accuracy: 98.79166666666667%
# Test: Loss 1.074610222503543, Accuracy: 87.2%
# Epoch: 58
# Train: Loss: 0.03265817398217526, Accuracy: 98.86666666666666%
# Test: Loss 0.9900987446308136, Accuracy: 87.85%
# Epoch: 59
# Train: Loss: 0.040179416804069966, Accuracy: 98.54166666666667%
# Test: Loss 1.0515651520341636, Accuracy: 87.5%
# Epoch: 60
# Train: Loss: 0.03211748492212792, Accuracy: 98.91666666666667%
# Test: Loss 1.0271327115595341, Accuracy: 88.025%
# Epoch: 61
# Train: Loss: 0.020902169397231773, Accuracy: 99.225%
# Test: Loss 1.0565249133855104, Accuracy: 87.6%
# Epoch: 62
# Train: Loss: 0.026100799396832977, Accuracy: 99.05833333333334%
# Test: Loss 1.1548363387584686, Accuracy: 87.45%
# Epoch: 63
# Train: Loss: 0.03205036403960548, Accuracy: 98.94166666666666%
# Test: Loss 1.0720007486641407, Accuracy: 87.525%
# Epoch: 64
# Train: Loss: 0.029640521834335232, Accuracy: 99.05%
# Test: Loss 1.1329892970621587, Accuracy: 87.5%
# Epoch: 65
# Train: Loss: 0.032390330963244195, Accuracy: 98.94166666666666%
# Test: Loss 1.0793330542743207, Accuracy: 87.375%
# Epoch: 66
# Train: Loss: 0.0334888957109797, Accuracy: 98.8625%
# Test: Loss 1.0306322857737542, Accuracy: 87.2%
# Epoch: 67
# Train: Loss: 0.02873152497098393, Accuracy: 98.99583333333334%
# Test: Loss 1.1179320961236954, Accuracy: 87.375%
# Epoch: 68
# Train: Loss: 0.02914514366960551, Accuracy: 99.025%
# Test: Loss 1.1568702906370163, Accuracy: 87.45%
# Epoch: 69
# Train: Loss: 0.023460707060197213, Accuracy: 99.17916666666666%
# Test: Loss 1.1983183920383453, Accuracy: 87.275%
# Epoch: 70
# Train: Loss: 0.028452280478389488, Accuracy: 98.95833333333333%
# Test: Loss 1.155855731666088, Accuracy: 87.05%
# Epoch: 71
# Train: Loss: 0.021697608623132206, Accuracy: 99.2375%
# Test: Loss 1.1796809576451779, Accuracy: 87.9%
# Epoch: 72
# Train: Loss: 0.02157373700286674, Accuracy: 99.18333333333334%
# Test: Loss 1.2014174364507197, Accuracy: 87.15%
# Epoch: 73
# Train: Loss: 0.02637669244892701, Accuracy: 99.0625%
# Test: Loss 1.248144118487835, Accuracy: 87.225%
# Epoch: 74
# Train: Loss: 0.027235789614496752, Accuracy: 99.07916666666667%
# Test: Loss 1.245498164743185, Accuracy: 86.8%
# Epoch: 75
# Train: Loss: 0.02558575720765172, Accuracy: 99.0875%
# Test: Loss 1.4346608608961104, Accuracy: 86.775%
# Epoch: 76
# Train: Loss: 0.02999468237203473, Accuracy: 98.99583333333334%
# Test: Loss 1.1442580871284007, Accuracy: 87.5%
# Epoch: 77
# Train: Loss: 0.024985429934713466, Accuracy: 99.20833333333333%
# Test: Loss 1.2023263975977898, Accuracy: 87.225%
# Epoch: 78
# Train: Loss: 0.02077873530499043, Accuracy: 99.28333333333333%
# Test: Loss 1.2283410489559174, Accuracy: 87.675%
# Epoch: 79
# Train: Loss: 0.033394669557492304, Accuracy: 98.9%
# Test: Loss 1.1609818458557128, Accuracy: 87.625%
# Epoch: 80
# Train: Loss: 0.021250414097751975, Accuracy: 99.19166666666666%
# Test: Loss 1.2150770135223865, Accuracy: 87.575%
# Epoch: 81
# Train: Loss: 0.015310830191901914, Accuracy: 99.4625%
# Test: Loss 1.2001564137637615, Accuracy: 87.35%
# Epoch: 82
# Train: Loss: 0.028636339254505098, Accuracy: 99.00833333333334%
# Test: Loss 1.2179351627826691, Accuracy: 86.875%
# Epoch: 83
# Train: Loss: 0.02810987465912452, Accuracy: 99.12083333333334%
# Test: Loss 1.258217480778694, Accuracy: 87.0%
# Epoch: 84
# Train: Loss: 0.02738816832231047, Accuracy: 99.0125%
# Test: Loss 1.2226124376058578, Accuracy: 87.4%
# Epoch: 85
# Train: Loss: 0.021434737319517203, Accuracy: 99.22083333333333%
# Test: Loss 1.2682786144316196, Accuracy: 87.075%
# Epoch: 86
# Train: Loss: 0.02228186417081209, Accuracy: 99.20416666666667%
# Test: Loss 1.1953783094882966, Accuracy: 87.525%
# Epoch: 87
# Train: Loss: 0.020451167821859902, Accuracy: 99.325%
# Test: Loss 1.3002920746803284, Accuracy: 87.55%
# Epoch: 88
# Train: Loss: 0.01993862462935188, Accuracy: 99.3125%
# Test: Loss 1.4506945431232452, Accuracy: 87.525%
# Epoch: 89
# Train: Loss: 0.0278457348917982, Accuracy: 99.07916666666667%
# Test: Loss 1.2429328456521034, Accuracy: 87.375%
# Epoch: 90
# Train: Loss: 0.023457594674224917, Accuracy: 99.25416666666666%
# Test: Loss 1.3003568395972251, Accuracy: 87.775%
# Epoch: 91
# Train: Loss: 0.020623361657787123, Accuracy: 99.26666666666667%
# Test: Loss 1.4051201090216636, Accuracy: 86.975%
# Epoch: 92
# Train: Loss: 0.015934386456198504, Accuracy: 99.42083333333333%
# Test: Loss 1.3284780398011207, Accuracy: 87.35%
# Epoch: 93
# Train: Loss: 0.017702205357659297, Accuracy: 99.38333333333334%
# Test: Loss 1.3247939057648181, Accuracy: 87.475%
# Epoch: 94
# Train: Loss: 0.027271493192862786, Accuracy: 99.05833333333334%
# Test: Loss 1.3475634463131427, Accuracy: 87.8%
# Epoch: 95
# Train: Loss: 0.02959979803757354, Accuracy: 99.02083333333333%
# Test: Loss 1.3155711457133292, Accuracy: 87.625%
# Epoch: 96
# Train: Loss: 0.01807638371727762, Accuracy: 99.38333333333334%
# Test: Loss 1.3422950252890586, Accuracy: 87.175%
# Epoch: 97
# Train: Loss: 0.022643637088670707, Accuracy: 99.2625%
# Test: Loss 1.4803201496601104, Accuracy: 86.975%
# Epoch: 98
# Train: Loss: 0.013350392402905224, Accuracy: 99.55%
# Test: Loss 1.4014185786247253, Accuracy: 87.1%
# Epoch: 99
# Train: Loss: 0.013392457890646862, Accuracy: 99.56666666666666%
# Test: Loss 1.4663612633943557, Accuracy: 87.025%
# Epoch: 100
# Train: Loss: 0.017857458882053832, Accuracy: 99.3875%
# Test: Loss 1.4329191438853741, Accuracy: 87.175%

# %% [markdown]
# ## Individual Model Accuracy

# %%
for i in range(len(confused_classes)):
    print("Extra Model #{}".format(i))

    num_classes = len(confused_classes[i])

    class_correct = [0. for _ in range(num_classes)]
    total_correct = [0. for _ in range(num_classes)]

    all_labels = torch.Tensor()
    all_predicted = torch.Tensor()

    with torch.no_grad():
        for images, labels in train_subset_loaders[i]:
            images, labels = images.to(device), labels.to(device)
            outputs = extra_models[i](images)
            _, predicted = outputs.max(1)
            c = (predicted == labels).squeeze()

            all_labels = torch.cat((all_labels, labels))
            all_predicted = torch.cat((all_predicted, predicted))
            
            for j in range(100):
                label = labels[j]
                class_correct[label] += c[j].item()
                total_correct[label] += 1
            
    for j in range(num_classes):
        k = maps[i][1][j] # index to class map
        print("Accuracy of {}: {:.2f}%".format(output_label(k), class_correct[j] * 100 / total_correct[j]))
    
    print(confusion_matrix(all_labels, all_predicted))
# Out:
# Extra Model #0
# Accuracy of T-shirt/Top: 99.97%
# Accuracy of Shirt: 99.40%
# [[5998    2]
#  [  36 5964]]
# Extra Model #1
# Accuracy of Pullover: 99.40%
# Accuracy of Coat: 97.72%
# Accuracy of Shirt: 99.83%
# [[5964    3   33]
#  [  33 5863  104]
#  [   9    1 5990]]
# Extra Model #2
# Accuracy of T-shirt/Top: 98.73%
# Accuracy of Dress: 98.97%
# Accuracy of Coat: 99.48%
# Accuracy of Shirt: 98.98%
# [[5924    6    1   69]
#  [   5 5938   34   23]
#  [   3    4 5969   24]
#  [  43    1   17 5939]]

# %%
for i in range(len(confused_classes)):
    print("Extra Model #{}".format(i))

    num_classes = len(confused_classes[i])

    class_correct = [0. for _ in range(num_classes)]
    total_correct = [0. for _ in range(num_classes)]

    all_labels = torch.Tensor()
    all_predicted = torch.Tensor()

    with torch.no_grad():
        for images, labels in test_subset_loaders[i]:
            images, labels = images.to(device), labels.to(device)
            outputs = extra_models[i](images)
            _, predicted = outputs.max(1)
            c = (predicted == labels).squeeze()

            all_labels = torch.cat((all_labels, labels))
            all_predicted = torch.cat((all_predicted, predicted))
            
            for j in range(100):
                label = labels[j]
                class_correct[label] += c[j].item()
                total_correct[label] += 1
            
    for j in range(num_classes):
        k = maps[i][1][j] # index to class map
        print("Accuracy of {}: {:.2f}%".format(output_label(k), class_correct[j] * 100 / total_correct[j]))
    
    print(confusion_matrix(all_labels, all_predicted))
# Out:
# Extra Model #0
# Accuracy of T-shirt/Top: 91.70%
# Accuracy of Shirt: 85.30%
# [[917  83]
#  [147 853]]
# Extra Model #1
# Accuracy of Pullover: 88.00%
# Accuracy of Coat: 85.50%
# Accuracy of Shirt: 90.00%
# [[880  45  75]
#  [ 43 855 102]
#  [ 60  40 900]]
# Extra Model #2
# Accuracy of T-shirt/Top: 86.70%
# Accuracy of Dress: 91.10%
# Accuracy of Coat: 90.60%
# Accuracy of Shirt: 80.30%
# [[867  20   8 105]
#  [ 23 911  31  35]
#  [  6  16 906  72]
#  [108  18  71 803]]

# %%
confused_classes_to_repredict = [0, 2, 3, 4, 6]
class_to_model_idx_mapping = {0: 0, 2: 1, 3: 2, 4: 1, 6: 0}

# %% [markdown]
# ## Training Accuracy

# %%
class_correct = [0. for _ in range(10)]
total_correct = [0. for _ in range(10)]
accuracies_new = []

all_labels = torch.Tensor()
all_predicted = torch.Tensor()

with torch.no_grad():
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        # if the batch of predicted results includes a prediction of a low accuracy class

        for i in range(len(confused_classes_to_repredict)):
            if confused_classes_to_repredict[i] in predicted:
                # run the batch through the second cNN trained on low accuracy classes
                outputs_new = extra_models[class_to_model_idx_mapping[confused_classes_to_repredict[i]]](images)
                _, predicted_new = outputs_new.max(1)
                # swap out predictions for select* classes from the first model for predictions from the second model
                predicted_temp = predicted
                index = 0
                for j in predicted:
                    if j == confused_classes_to_repredict[i]:
                        # swap the old prediction for the one from the second model
                        predicted_temp[index] = maps[class_to_model_idx_mapping[confused_classes_to_repredict[i]]][1][predicted_new[index].item()] # idx to class map
                    index += 1
                predicted = predicted_temp

        c = (predicted == labels).squeeze()

        all_labels = torch.cat((all_labels, labels))
        all_predicted = torch.cat((all_predicted, predicted))
        
        for i in range(100):
            label = labels[i]
            class_correct[label] += c[i].item()
            total_correct[label] += 1

accuracies_total_change = 0
for i in range(10):
    accuracies_new.append(class_correct[i] * 100 / total_correct[i])
    accuracies_total_change += (accuracies_new[i] - accuracies_train[i])
    print("Accuracy of {}: {:.2f}%, Change: {:.2f}%".format(output_label(i), accuracies_new[i], accuracies_new[i] - accuracies_train[i]))

print("Total accuracy change: {:.2f}%".format(accuracies_total_change))
# Out:
# Accuracy of T-shirt/Top: 99.85%, Change: 1.17%
# Accuracy of Trouser: 99.80%, Change: 0.00%
# Accuracy of Pullover: 98.88%, Change: 0.52%
# Accuracy of Dress: 98.70%, Change: -1.03%
# Accuracy of Coat: 97.52%, Change: -1.35%
# Accuracy of Sandal: 100.00%, Change: 0.00%
# Accuracy of Shirt: 99.35%, Change: 8.28%
# Accuracy of Sneaker: 99.97%, Change: 0.00%
# Accuracy of Bag: 99.78%, Change: 0.00%
# Accuracy of Ankle Boot: 99.23%, Change: 0.00%
# Total accuracy change: 7.58%

# %%
confusion_matrix(all_labels, all_predicted)
# Out:
# array([[5991,    1,    4,    1,    1,    0,    2,    0,    0,    0],
#        [   3, 5988,    0,    7,    1,    0,    1,    0,    0,    0],
#        [  27,    0, 5933,    3,    3,    0,   34,    0,    0,    0],
#        [  25,    0,    5, 5922,   21,    0,   26,    1,    0,    0],
#        [   9,    0,   33,    0, 5851,    0,  107,    0,    0,    0],
#        [   0,    0,    0,    0,    0, 6000,    0,    0,    0,    0],
#        [  36,    0,    2,    1,    0,    0, 5961,    0,    0,    0],
#        [   0,    0,    0,    0,    0,    2,    0, 5998,    0,    0],
#        [   7,    0,    1,    0,    0,    0,    5,    0, 5987,    0],
#        [   0,    0,    0,    0,    0,    3,    0,   43,    0, 5954]],
#       dtype=int64)

# %% [markdown]
# ## Test Accuracy

# %%
class_correct = [0. for _ in range(10)]
total_correct = [0. for _ in range(10)]
accuracies_new = []

all_labels = torch.Tensor()
all_predicted = torch.Tensor()

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        # if the batch of predicted results includes a prediction of a low accuracy class

        for i in range(len(confused_classes_to_repredict)):
            if confused_classes_to_repredict[i] in predicted:
                # run the batch through the second cNN trained on low accuracy classes
                outputs_new = extra_models[class_to_model_idx_mapping[confused_classes_to_repredict[i]]](images)
                _, predicted_new = outputs_new.max(1)
                # swap out predictions for select* classes from the first model for predictions from the second model
                predicted_temp = predicted
                index = 0
                for j in predicted:
                    if j == confused_classes_to_repredict[i]:
                        # swap the old prediction for the one from the second model
                        predicted_temp[index] = maps[class_to_model_idx_mapping[confused_classes_to_repredict[i]]][1][predicted_new[index].item()] # idx to class map
                    index += 1
                predicted = predicted_temp

        c = (predicted == labels).squeeze()

        all_labels = torch.cat((all_labels, labels))
        all_predicted = torch.cat((all_predicted, predicted))
        
        for i in range(100):
            label = labels[i]
            class_correct[label] += c[i].item()
            total_correct[label] += 1

accuracies_total_change = 0
for i in range(10):
    accuracies_new.append(class_correct[i] * 100 / total_correct[i])
    accuracies_total_change += (accuracies_new[i] - accuracies_test[i])
    print("Accuracy of {}: {:.2f}%, Change: {:.2f}%".format(output_label(i), accuracies_new[i], accuracies_new[i] - accuracies_test[i]))

print("Total accuracy change: {:.2f}%".format(accuracies_total_change))
# Out:
# Accuracy of T-shirt/Top: 90.00%, Change: 1.00%
# Accuracy of Trouser: 98.20%, Change: 0.00%
# Accuracy of Pullover: 83.50%, Change: -1.00%
# Accuracy of Dress: 87.00%, Change: -5.30%
# Accuracy of Coat: 83.20%, Change: -4.60%
# Accuracy of Sandal: 98.10%, Change: 0.00%
# Accuracy of Shirt: 79.10%, Change: 11.30%
# Accuracy of Sneaker: 97.00%, Change: 0.00%
# Accuracy of Bag: 97.10%, Change: 0.00%
# Accuracy of Ankle Boot: 95.00%, Change: 0.00%
# Total accuracy change: 1.40%

# %%
confusion_matrix(all_labels, all_predicted)
# Out:
# array([[900,   0,  12,   6,   2,   0,  76,   1,   3,   0],
#        [  3, 982,   1,   6,   2,   1,   5,   0,   0,   0],
#        [ 42,   0, 835,   5,  40,   0,  76,   2,   0,   0],
#        [ 57,   7,  10, 870,  24,   0,  30,   0,   2,   0],
#        [  8,   0,  40,   9, 832,   0, 109,   0,   2,   0],
#        [  0,   0,   0,   0,   0, 981,   1,  13,   0,   5],
#        [140,   1,  36,   8,  22,   0, 791,   0,   2,   0],
#        [  0,   0,   0,   0,   0,  10,   0, 970,   0,  20],
#        [  6,   0,   4,   0,   3,   1,  11,   3, 971,   1],
#        [  0,   0,   0,   0,   0,   5,   1,  44,   0, 950]], dtype=int64)

# %% [markdown]
# # Extras

# %%
# https://debuggercafe.com/visualizing-filters-and-feature-maps-in-convolutional-neural-networks-using-pytorch/
model_weights = [] # we will save the conv layer weights in this list
conv_layers = [] # we will save the 49 conv layers in this list
# get all the model children as list
model_children = list(model.children())

# %%
# counter to keep count of the conv layers
counter = 0 
# append all the conv layers and their respective weights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter += 1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for child in model_children[i].children():
            if type(child) == nn.Conv2d:
                counter += 1
                model_weights.append(child.weight)
                conv_layers.append(child)
print(f"Total convolutional layers: {counter}")
# Out:
# Total convolutional layers: 2

# %%
# take a look at the conv layers and the respective weights
for weight, conv in zip(model_weights, conv_layers):
    # print(f"WEIGHT: {weight} \nSHAPE: {weight.shape}")
    print(f"CONV: {conv} ====> SHAPE: {weight.shape}")
# Out:
# CONV: Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) ====> SHAPE: torch.Size([32, 1, 3, 3])
# CONV: Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1)) ====> SHAPE: torch.Size([64, 32, 3, 3])

# %%
# visualize the first conv layer filters
plt.figure(figsize=(20, 17))
for i, filter in enumerate(model_weights[0].cpu()):
    plt.subplot(8, 8, i+1) # (8, 8) because in conv0 we have 7x7 filters and total of 64 (see printed shapes)
    plt.imshow(filter[0, :, :].detach(), cmap='gray')
    plt.axis('off')
    plt.savefig('./diagrams/filter1.png')
plt.show()

# %%
# visualize the second conv layer filters
plt.figure(figsize=(20, 17))
for i, filter in enumerate(model_weights[1].cpu()):
    plt.subplot(8, 8, i+1) # (8, 8) because in conv0 we have 7x7 filters and total of 64 (see printed shapes)
    plt.imshow(filter[0, :, :].detach(), cmap='gray')
    plt.axis('off')
    plt.savefig('./diagrams/filter2.png')
plt.show()

# %%
print(model_weights[0].cpu())
# Out:
# Parameter containing:
# tensor([[[[-1.2302e-01,  3.7347e-01, -2.2248e-01],
#           [-5.3053e-01,  4.8822e-01,  4.6635e-02],
#           [ 9.9103e-02,  3.0692e-01, -3.9338e-01]]],
#
#
#         [[[ 1.4458e-01,  2.5009e-01,  4.7892e-01],
#           [-5.8721e-02, -1.7690e-01,  1.2074e-01],
#           [-3.8059e-02, -7.2988e-01, -3.2631e-01]]],
#
#
#         [[[ 1.5373e-01, -4.6641e-01,  5.1424e-01],
#           [-3.9252e-01, -2.3984e-01,  1.3329e-01],
#           [ 3.2630e-01,  4.0333e-01,  3.9167e-02]]],
#
#
#         [[[-1.3765e-01,  3.9300e-01,  8.5180e-02],
#           [ 7.3049e-02,  2.2048e-01, -3.2635e-02],
#           [ 4.4386e-01,  8.9833e-01,  2.1400e-01]]],
#
#
#         [[[-1.7941e-01, -1.7735e-01,  1.1419e-01],
#           [-5.8480e-01, -9.4403e-01, -3.4705e-01],
#           [ 1.5568e-01, -2.8263e-01,  2.5899e-01]]],
#
#
#         [[[-4.8319e-01,  4.6231e-01, -1.9453e-01],
#           [-9.4509e-01, -1.0771e-01,  1.1423e-01],
#           [ 1.9046e-02, -3.2616e-01,  7.3947e-02]]],
#
#
#         [[[ 5.0877e-01,  2.2763e-01, -4.2635e-01],
#           [-2.6729e-01,  8.9159e-03, -5.2479e-01],
#           [ 4.0061e-01,  3.8695e-01, -2.4647e-02]]],
#
#
#         [[[-1.3867e-01, -5.4513e-01,  2.5053e-01],
#           [ 4.9282e-01, -3.7757e-01, -5.2517e-02],
#           [ 2.9025e-01, -2.4906e-01,  3.9577e-01]]],
#
#
#         [[[-2.7352e-02,  3.0887e-01,  3.2780e-01],
#           [ 2.7574e-01,  3.1624e-01, -6.7645e-01],
#           [-6.3266e-02, -3.2957e-01,  3.6229e-01]]],
#
#
#         [[[ 1.6259e-01,  1.0786e-01, -2.9403e-01],
#           [-2.8687e-01,  5.5748e-01, -4.2743e-01],
#           [-3.9348e-01, -1.2722e-01,  3.3589e-01]]],
#
#
#         [[[-4.3264e-01,  2.5083e-01,  1.1683e-01],
#           [-2.5334e-01,  7.3648e-02,  3.0494e-01],
#           [ 4.1065e-01, -5.6400e-01,  9.3391e-02]]],
#
#
#         [[[ 8.3839e-02,  2.4959e-01,  5.1109e-01],
#           [-5.7893e-01, -4.9919e-01,  2.8053e-02],
#           [-2.8555e-01, -7.6038e-02, -2.9798e-01]]],
#
#
#         [[[ 7.6874e-02, -3.0985e-01,  2.6579e-01],
#           [-3.5440e-01,  2.3688e-01,  3.9333e-01],
#           [-3.8573e-01,  8.2395e-02,  5.7380e-01]]],
#
#
#         [[[-1.3080e-01,  5.7936e-01,  5.0197e-01],
#           [-5.2983e-02,  9.0930e-02, -2.2508e-02],
#           [-8.8991e-02, -4.9427e-01,  4.4276e-01]]],
#
#
#         [[[ 1.2455e-01,  6.9007e-02, -6.3924e-02],
#           [-4.3276e-01,  5.2841e-01, -1.4695e-01],
#           [ 3.0372e-01, -5.3367e-01,  2.2068e-01]]],
#
#
#         [[[ 5.5064e-01, -4.0147e-01, -7.3954e-02],
#           [-3.4091e-01,  1.8138e-01, -1.6906e-01],
#           [-5.4916e-02, -5.7752e-01,  2.1859e-01]]],
#
#
#         [[[ 6.2547e-01, -4.6497e-01, -1.4945e-01],
#           [-1.6491e-01, -2.8590e-02,  1.6554e-01],
#           [-4.1306e-01,  3.8072e-01,  2.8734e-02]]],
#
#
#         [[[ 1.4233e-01,  5.8515e-02,  5.2262e-02],
#           [ 4.8752e-02, -6.6392e-01, -7.1263e-01],
#           [-2.4624e-01, -1.2652e+00, -2.0273e-01]]],
#
#
#         [[[-3.7673e-01, -6.3584e-02,  4.1295e-01],
#           [ 3.3196e-01, -4.4555e-01, -2.9562e-01],
#           [-1.9025e-01,  3.3389e-01,  1.0989e-02]]],
#
#
#         [[[-1.8842e-01,  4.4001e-01, -4.2681e-01],
#           [ 6.1394e-02, -2.4780e-01,  4.3286e-01],
#           [ 2.9582e-01, -4.4678e-01,  1.9387e-01]]],
#
#
#         [[[-5.5413e-01,  2.5124e-01, -8.9769e-02],
#           [ 1.5524e-01,  3.9023e-01, -7.7546e-01],
#           [ 1.2724e-01, -2.8971e-01,  1.5017e-01]]],
#
#
#         [[[-2.2498e-01, -5.1645e-01, -9.5862e-02],
#           [-1.4376e-02,  3.8384e-01,  3.1302e-01],
#           [-3.4248e-01,  3.4774e-01, -3.6461e-01]]],
#
#
#         [[[ 3.6769e-01,  4.3642e-01, -6.2530e-01],
#           [-4.1408e-01, -2.2202e-01, -3.9532e-01],
#           [ 2.3340e-01, -1.9685e-01,  1.6738e-01]]],
#
#
#         [[[-6.5673e-02, -6.3475e-01, -2.1204e-01],
#           [-4.0460e-03,  2.4766e-01, -5.3223e-02],
#           [ 2.9820e-01,  4.6902e-01, -9.2236e-02]]],
#
#
#         [[[-6.8181e-03,  2.6655e-01, -5.8949e-01],
#           [ 4.3460e-02, -4.5537e-01,  6.1519e-02],
#           [-6.4464e-03,  1.1461e-01,  4.9814e-01]]],
#
#
#         [[[ 2.3551e-01,  1.1486e-03,  1.4519e-01],
#           [ 2.6487e-02, -1.7577e-01, -6.5216e-01],
#           [-3.4245e-01,  4.3675e-01,  4.3478e-01]]],
#
#
#         [[[ 3.4519e-01,  2.3110e-01,  1.8828e-01],
#           [-6.3739e-01, -4.7561e-01, -3.1792e-01],
#           [ 4.5255e-01,  1.9276e-01,  1.0821e-04]]],
#
#
#         [[[-4.3141e-01, -4.5035e-01,  4.5314e-01],
#           [ 1.7115e-01, -4.9782e-02,  4.9631e-02],
#           [-4.7836e-01, -2.4804e-01,  3.8084e-01]]],
#
#
#         [[[ 3.3251e-01, -4.5415e-01, -5.2972e-01],
#           [ 2.6211e-01,  3.6394e-01,  4.6053e-01],
#           [-2.4942e-01,  1.3563e-01, -1.0575e-01]]],
#
#
#         [[[-4.9761e-01,  5.6990e-01, -7.6592e-03],
#           [ 1.2673e-01, -1.7553e-01,  8.4104e-02],
#           [-4.8445e-01,  5.0894e-01, -3.2693e-02]]],
#
#
#         [[[-8.2689e-02, -3.3173e-01,  4.3348e-01],
#           [-4.2670e-01,  3.6693e-01,  6.3501e-02],
#           [ 5.4157e-01, -1.9479e-01, -3.6832e-01]]],
#
#
#         [[[-3.5937e-01, -2.2842e-01,  3.8861e-01],
#           [ 5.8471e-01, -3.3102e-01,  3.4263e-01],
#           [ 7.9715e-02,  2.6819e-02, -3.2224e-01]]]], requires_grad=True)

# %%
plt.imsave('./diagrams/pullover.png', image.squeeze(), cmap="gray")

# %%
import cv2 as cv

# read and visualize an image
img = cv.imread(f"./diagrams/pullover.png")
# img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# define the transforms
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((28, 28)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
])

img = np.array(img)
# apply the transforms
img = transform(img)
print(img.size())
# unsqueeze to add a batch dimension
img = img.unsqueeze(0)
print(img.size())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-c79eaaf547ff> in <module>
# ----> 1 import cv2 as cv
#       2
#       3 # read and visualize an image
#       4 img = cv.imread(f"./diagrams/pullover.png")
#       5 # img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# pass the image through all the layers
img = img.to(device)
results = [conv_layers[0](img)]
for i in range(1, len(conv_layers)):
    # pass the result from the last layer to the next layer
    results.append(conv_layers[i](results[-1]))
# make a copy of the `results`
outputs = results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-b737c019f94f> in <module>
#       1 # pass the image through all the layers
# ----> 2 img = img.to(device)
#       3 results = [conv_layers[0](img)]
#       4 for i in range(1, len(conv_layers)):
#       5     # pass the result from the last layer to the next layer
#
# NameError: name 'img' is not defined

# %%
# visualize 64 features from each layer 
# (although there are more feature maps in the upper layers)
for num_layer in range(len(outputs)):
    plt.figure(figsize=(30, 30))
    layer_viz = outputs[num_layer][0, :, :, :]
    layer_viz = layer_viz.data
    print(layer_viz.size())
    for i, filter in enumerate(layer_viz):
        if i == 64: # we will visualize only 8x8 blocks from each layer
            break
        plt.subplot(8, 8, i + 1)
        plt.imshow(filter.cpu(), cmap='gray')
        plt.axis("off")
    print(f"Saving layer {num_layer} feature maps...")
    plt.savefig(f"./diagrams/layer_{num_layer}.png")
    # plt.show()
    plt.close()
# Out:
# torch.Size([32, 28, 28])
# Saving layer 0 feature maps...
# torch.Size([64, 26, 26])
# Saving layer 1 feature maps...
